# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Activation,BatchNormalization,Input,Embedding,Dot,Dense,Flatten
from tensorflow.keras.callbacks import ModelCheckpoint,LearningRateScheduler,TensorBoard,EarlyStopping

# from wordcloud import WordCloud
# %matplotlib inline

# %% [markdown]
# ### READING ANIMELIST.CSV

# %%
import os

# %%
INPUT_DIR = os.path.join("..","artifacts","raw")

# %%
rating_df = pd.read_csv(INPUT_DIR+"/animelist.csv" , low_memory=True,usecols=["user_id","anime_id","rating"])

# %%
rating_df.head()
# Out:
#    user_id  anime_id  rating
# 0        0        67       9
# 1        0      6702       7
# 2        0       242      10
# 3        0      4898       0
# 4        0        21      10

# %%
len(rating_df)
# Out:
# 9000000

# %% [markdown]
# #### DATA PROCESSING

# %%
n_ratings = rating_df["user_id"].value_counts()

# %%
n_ratings[n_ratings>200].index
# Out:
# Index([20807, 11100, 22022, 16869, 10255,  4773, 28205,  6852, 18355, 26654,
#        ...
#         3667, 16843,  3893, 26483, 25134, 16540,  8834, 13287, 16905, 18756],
#       dtype='int64', name='user_id', length=14480)

# %%
rating_df = rating_df[rating_df["user_id"].isin(n_ratings[n_ratings>=400].index)].copy()

# %%
user_ids = rating_df["user_id"].unique().tolist()
user_ids
# Out:
# [2,
#  6,
#  12,
#  16,
#  17,
#  19,
#  21,
#  41,
#  42,
#  44,
#  47,
#  53,
#  55,
#  60,
#  66,
#  73,
#  74,
#  85,
#  89,
#  90,
#  94,
#  98,
#  102,
#  108,
#  111,
#  112,
#  120,
#  121,
#  122,
#  135,
#  145,
#  146,
#  147,
#  153,
#  155,
#  156,
#  172,
#  174,
#  184,
#  190,
#  193,
#  194,
#  198,
#  204,
#  205,
#  209,
#  214,
#  219,
#  222,
#  227,
#  228,
#  235,
#  238,
#  240,
#  243,
#  248,
#  251,
#  252,
#  257,
#  264,
#  267,
#  272,
#  274,
#  275,
#  284,
#  285,
#  286,
#  290,
#  291,
#  293,
#  300,
#  301,
#  306,
#  308,
#  310,
#  313,
#  314,
#  316,
#  320,
#  321,
#  324,
#  325,
#  326,
#  327,
#  330,
#  336,
#  340,
#  345,
#  346,
#  349,
#  350,
#  366,
#  367,
#  371,
#  372,
#  375,
#  381,
#  382,
#  386,
#  389,
#  398,
#  405,
#  406,
#  413,
#  414,
#  418,
#  423,
#  426,
#  428,
#  431,
#  432,
#  436,
#  437,
#  438,
#  440,
#  442,
#  444,
#  445,
#  446,
#  455,
#  457,
#  459,
#  464,
#  467,
#  468,
#  469,
#  478,
#  481,
#  483,
#  484,
#  486,
#  493,
#  498,
#  500,
#  516,
#  517,
#  519,
#  524,
#  526,
#  529,
#  531,
#  538,
#  542,
#  547,
#  549,
#  559,
#  563,
#  564,
#  566,
#  569,
#  571,
#  577,
#  590,
#  593,
#  596,
#  601,
#  603,
#  608,
#  613,
#  614,
#  617,
#  620,
#  629,
#  631,
#  639,
#  642,
#  643,
#  644,
#  649,
#  652,
#  655,
#  656,
#  662,
#  664,
#  673,
#  674,
#  680,
#  681,
#  683,
#  686,
#  689,
#  694,
#  699,
#  711,
#  713,
#  714,
#  716,
#  719,
#  725,
#  728,
#  730,
#  731,
#  732,
#  734,
#  745,
#  746,
#  748,
#  753,
#  760,
#  764,
#  770,
#  774,
#  776,
#  778,
#  779,
#  780,
#  781,
#  783,
#  785,
#  791,
#  792,
#  793,
#  794,
#  807,
#  815,
#  819,
#  820,
#  822,
#  823,
#  830,
#  831,
#  836,
#  841,
#  842,
#  848,
#  849,
#  851,
#  853,
#  858,
#  859,
#  860,
#  864,
#  865,
#  866,
#  869,
#  870,
#  871,
#  876,
#  882,
#  888,
#  889,
#  890,
#  891,
#  894,
#  897,
#  899,
#  901,
#  902,
#  911,
#  912,
#  915,
#  917,
#  921,
#  925,
#  927,
#  932,
#  934,
#  936,
#  938,
#  943,
#  944,
#  945,
#  948,
#  950,
#  953,
#  965,
#  967,
#  969,
#  970,
#  974,
#  976,
#  979,
#  984,
#  985,
#  986,
#  989,
#  994,
#  995,
#  997,
#  998,
#  1000,
#  1002,
#  1004,
#  1008,
#  1010,
#  1016,
#  1021,
#  1023,
#  1025,
#  1036,
#  1043,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  1063,
#  1066,
#  1073,
#  1079,
#  1091,
#  1092,
#  1094,
#  1096,
#  1101,
#  1107,
#  1113,
#  1115,
#  1116,
#  1117,
#  1127,
#  1128,
#  1133,
#  1139,
#  1150,
#  1162,
#  1167,
#  1170,
#  1173,
#  1177,
#  1179,
#  1184,
#  1185,
#  1187,
#  1192,
#  1197,
#  1203,
#  1205,
#  1207,
#  1209,
#  1210,
#  1218,
#  1220,
#  1227,
#  1231,
#  1235,
#  1239,
#  1244,
#  1245,
#  1246,
#  1247,
#  1248,
#  1249,
#  1250,
#  1259,
#  1264,
#  1266,
#  1273,
#  1286,
#  1289,
#  1296,
#  1297,
#  1309,
#  1310,
#  1316,
#  1329,
#  1334,
#  1347,
#  1348,
#  1353,
#  1356,
#  1357,
#  1358,
#  1365,
#  1367,
#  1371,
#  1373,
#  1374,
#  1392,
#  1393,
#  1395,
#  1396,
#  1397,
#  1400,
#  1404,
#  1407,
#  1409,
#  1412,
#  1417,
#  1420,
#  1421,
#  1430,
#  1433,
#  1437,
#  1439,
#  1440,
#  1443,
#  1450,
#  1453,
#  1463,
#  1469,
#  1470,
#  1483,
#  1487,
#  1488,
#  1491,
#  1493,
#  1495,
#  1496,
#  1498,
#  1504,
#  1514,
#  1523,
#  1529,
#  1552,
#  1558,
#  1561,
#  1563,
#  1565,
#  1567,
#  1568,
#  1570,
#  1571,
#  1581,
#  1582,
#  1596,
#  1599,
#  1601,
#  1606,
#  1609,
#  1611,
#  1612,
#  1616,
#  1619,
#  1626,
#  1627,
#  1629,
#  1630,
#  1631,
#  1640,
#  1641,
#  1650,
#  1659,
#  1664,
#  1665,
#  1667,
#  1671,
#  1679,
#  1682,
#  1690,
#  1694,
#  1697,
#  1708,
#  1710,
#  1720,
#  1723,
#  1731,
#  1733,
#  1739,
#  1747,
#  1749,
#  1750,
#  1752,
#  1755,
#  1756,
#  1760,
#  1766,
#  1773,
#  1775,
#  1783,
#  1792,
#  1795,
#  1796,
#  1800,
#  1801,
#  1803,
#  1806,
#  1812,
#  1813,
#  1817,
#  1820,
#  1822,
#  1833,
#  1840,
#  1850,
#  1858,
#  1864,
#  1870,
#  1874,
#  1878,
#  1879,
#  1883,
#  1886,
#  1891,
#  1893,
#  1894,
#  1895,
#  1897,
#  1900,
#  1902,
#  1910,
#  1911,
#  1924,
#  1925,
#  1930,
#  1938,
#  1941,
#  1946,
#  1947,
#  1950,
#  1957,
#  1961,
#  1962,
#  1963,
#  1967,
#  1973,
#  1975,
#  1989,
#  1996,
#  2002,
#  2003,
#  2006,
#  2009,
#  2018,
#  2021,
#  2030,
#  2033,
#  2037,
#  2043,
#  2046,
#  2047,
#  2058,
#  2059,
#  2060,
#  2061,
#  2063,
#  2073,
#  2079,
#  2088,
#  2092,
#  2095,
#  2098,
#  2100,
#  2109,
#  2111,
#  2123,
#  2132,
#  2135,
#  2136,
#  2143,
#  2145,
#  2158,
#  2159,
#  2161,
#  2162,
#  2169,
#  2170,
#  2174,
#  2179,
#  2180,
#  2189,
#  2191,
#  2194,
#  2204,
#  2209,
#  2219,
#  2220,
#  2222,
#  2224,
#  2225,
#  2233,
#  2235,
#  2236,
#  2237,
#  2239,
#  2251,
#  2261,
#  2262,
#  2280,
#  2281,
#  2286,
#  2292,
#  2300,
#  2302,
#  2303,
#  2304,
#  2307,
#  2310,
#  2316,
#  2317,
#  2320,
#  2326,
#  2327,
#  2337,
#  2339,
#  2345,
#  2346,
#  2349,
#  2353,
#  2355,
#  2356,
#  2362,
#  2365,
#  2367,
#  2371,
#  2372,
#  2373,
#  2381,
#  2382,
#  2388,
#  2389,
#  2400,
#  2402,
#  2410,
#  2411,
#  2414,
#  2423,
#  2424,
#  2437,
#  2441,
#  2448,
#  2450,
#  2454,
#  2461,
#  2462,
#  2463,
#  2464,
#  2465,
#  2468,
#  2469,
#  2471,
#  2476,
#  2478,
#  2480,
#  2483,
#  2484,
#  2493,
#  2507,
#  2509,
#  2510,
#  2513,
#  2518,
#  2520,
#  2523,
#  2531,
#  2535,
#  2543,
#  2544,
#  2546,
#  2547,
#  2557,
#  2559,
#  2563,
#  2569,
#  2572,
#  2576,
#  2586,
#  2595,
#  2600,
#  2601,
#  2604,
#  2605,
#  2608,
#  2609,
#  2610,
#  2611,
#  2613,
#  2615,
#  2616,
#  2622,
#  2638,
#  2640,
#  2641,
#  2644,
#  2650,
#  2653,
#  2656,
#  2662,
#  2664,
#  2666,
#  2672,
#  2674,
#  2675,
#  2687,
#  2691,
#  2697,
#  2703,
#  2704,
#  2713,
#  2715,
#  2720,
#  2721,
#  2722,
#  2727,
#  2731,
#  2735,
#  2739,
#  2741,
#  2744,
#  2745,
#  2748,
#  2754,
#  2764,
#  2766,
#  2768,
#  2771,
#  2776,
#  2787,
#  2791,
#  2796,
#  2804,
#  2805,
#  2814,
#  2820,
#  2822,
#  2824,
#  2831,
#  2832,
#  2840,
#  2845,
#  2852,
#  2855,
#  2856,
#  2860,
#  2865,
#  2866,
#  2868,
#  2871,
#  2874,
#  2876,
#  2881,
#  2885,
#  2891,
#  2892,
#  2901,
#  2902,
#  2913,
#  2919,
#  2924,
#  2938,
#  2941,
#  2950,
#  2952,
#  2953,
#  2969,
#  2970,
#  2972,
#  2974,
#  2976,
#  2980,
#  2982,
#  2987,
#  2992,
#  2993,
#  2997,
#  2998,
#  3001,
#  3004,
#  3005,
#  3008,
#  3015,
#  3018,
#  3021,
#  3051,
#  3054,
#  3055,
#  3061,
#  3071,
#  3079,
#  3085,
#  3101,
#  3102,
#  3105,
#  3106,
#  3110,
#  3118,
#  3120,
#  3123,
#  3127,
#  3136,
#  3139,
#  3142,
#  3144,
#  3145,
#  3148,
#  3151,
#  3154,
#  3160,
#  3163,
#  3164,
#  3165,
#  3168,
#  3171,
#  3174,
#  3179,
#  3185,
#  3187,
#  3191,
#  3198,
#  3203,
#  3210,
#  3213,
#  3214,
#  3223,
#  3224,
#  3227,
#  3229,
#  3230,
#  3232,
#  3235,
#  3236,
#  3249,
#  3257,
#  3260,
#  3266,
#  3268,
#  3275,
#  3276,
#  3278,
#  3284,
#  3286,
#  3287,
#  3291,
#  3297,
#  3298,
#  3303,
#  3308,
#  3311,
#  3312,
#  3313,
#  3315,
#  3329,
#  3330,
#  3331,
#  3332,
#  3333,
#  3334,
#  3336,
#  3337,
#  3354,
#  3358,
#  3363,
#  3369,
#  3376,
#  3381,
#  3382,
#  3388,
#  3393,
#  3395,
#  3396,
#  3399,
#  3400,
#  3405,
#  3409,
#  3411,
#  3423,
#  3431,
#  3432,
#  3433,
#  3434,
#  3436,
#  3437,
#  3451,
#  3454,
#  3458,
#  3462,
#  3466,
#  3470,
#  3473,
#  3476,
#  3479,
#  3480,
#  3481,
#  3483,
#  3493,
#  3497,
#  3499,
#  3502,
#  3508,
#  3509,
#  3517,
#  3522,
#  3524,
#  3528,
#  3531,
#  3532,
#  3533,
#  3539,
#  3541,
#  3547,
#  3558,
#  3578,
#  3581,
#  3582,
#  3588,
#  3589,
#  3600,
#  3601,
#  3602,
#  3604,
#  3607,
#  3608,
#  3612,
#  3620,
#  3621,
#  3623,
#  3625,
#  3626,
#  3632,
#  3633,
#  3642,
#  3644,
#  3645,
#  3646,
#  3647,
#  3651,
#  3652,
#  3653,
#  3655,
#  3665,
#  3681,
#  3688,
#  3694,
#  3697,
#  3701,
#  3702,
#  3711,
#  3714,
#  3715,
#  3724,
#  3725,
#  3730,
#  3733,
#  3737,
#  3741,
#  3743,
#  3749,
#  3755,
#  3756,
#  3758,
#  3775,
#  3784,
#  3785,
#  3793,
#  3811,
#  3812,
#  3814,
#  3816,
#  3819,
#  3824,
#  3825,
#  3827,
#  3828,
#  3829,
#  3838,
#  3845,
#  3850,
#  3858,
#  3862,
#  3869,
#  3882,
#  3890,
#  3892,
#  3894,
#  3896,
#  3897,
#  3899,
#  3901,
#  3907,
#  3914,
#  3916,
#  3917,
#  3922,
#  3923,
#  3926,
#  3928,
#  3929,
#  3931,
#  3932,
#  3933,
#  3934,
#  3940,
#  3941,
#  3944,
#  3945,
#  3949,
#  3953,
#  3954,
#  3965,
#  3966,
#  3968,
#  3972,
#  3979,
#  3982,
#  3999,
#  4004,
#  4007,
#  4009,
#  4011,
#  4016,
#  4018,
#  4024,
#  4027,
#  4033,
#  4036,
#  4041,
#  4052,
#  4055,
#  4056,
#  4058,
#  ...]

# %%
user2user_encoded = {x : i for i , x in enumerate(user_ids)}
user2user_encoded
# Out:
# {2: 0,
#  6: 1,
#  12: 2,
#  16: 3,
#  17: 4,
#  19: 5,
#  21: 6,
#  41: 7,
#  42: 8,
#  44: 9,
#  47: 10,
#  53: 11,
#  55: 12,
#  60: 13,
#  66: 14,
#  73: 15,
#  74: 16,
#  85: 17,
#  89: 18,
#  90: 19,
#  94: 20,
#  98: 21,
#  102: 22,
#  108: 23,
#  111: 24,
#  112: 25,
#  120: 26,
#  121: 27,
#  122: 28,
#  135: 29,
#  145: 30,
#  146: 31,
#  147: 32,
#  153: 33,
#  155: 34,
#  156: 35,
#  172: 36,
#  174: 37,
#  184: 38,
#  190: 39,
#  193: 40,
#  194: 41,
#  198: 42,
#  204: 43,
#  205: 44,
#  209: 45,
#  214: 46,
#  219: 47,
#  222: 48,
#  227: 49,
#  228: 50,
#  235: 51,
#  238: 52,
#  240: 53,
#  243: 54,
#  248: 55,
#  251: 56,
#  252: 57,
#  257: 58,
#  264: 59,
#  267: 60,
#  272: 61,
#  274: 62,
#  275: 63,
#  284: 64,
#  285: 65,
#  286: 66,
#  290: 67,
#  291: 68,
#  293: 69,
#  300: 70,
#  301: 71,
#  306: 72,
#  308: 73,
#  310: 74,
#  313: 75,
#  314: 76,
#  316: 77,
#  320: 78,
#  321: 79,
#  324: 80,
#  325: 81,
#  326: 82,
#  327: 83,
#  330: 84,
#  336: 85,
#  340: 86,
#  345: 87,
#  346: 88,
#  349: 89,
#  350: 90,
#  366: 91,
#  367: 92,
#  371: 93,
#  372: 94,
#  375: 95,
#  381: 96,
#  382: 97,
#  386: 98,
#  389: 99,
#  398: 100,
#  405: 101,
#  406: 102,
#  413: 103,
#  414: 104,
#  418: 105,
#  423: 106,
#  426: 107,
#  428: 108,
#  431: 109,
#  432: 110,
#  436: 111,
#  437: 112,
#  438: 113,
#  440: 114,
#  442: 115,
#  444: 116,
#  445: 117,
#  446: 118,
#  455: 119,
#  457: 120,
#  459: 121,
#  464: 122,
#  467: 123,
#  468: 124,
#  469: 125,
#  478: 126,
#  481: 127,
#  483: 128,
#  484: 129,
#  486: 130,
#  493: 131,
#  498: 132,
#  500: 133,
#  516: 134,
#  517: 135,
#  519: 136,
#  524: 137,
#  526: 138,
#  529: 139,
#  531: 140,
#  538: 141,
#  542: 142,
#  547: 143,
#  549: 144,
#  559: 145,
#  563: 146,
#  564: 147,
#  566: 148,
#  569: 149,
#  571: 150,
#  577: 151,
#  590: 152,
#  593: 153,
#  596: 154,
#  601: 155,
#  603: 156,
#  608: 157,
#  613: 158,
#  614: 159,
#  617: 160,
#  620: 161,
#  629: 162,
#  631: 163,
#  639: 164,
#  642: 165,
#  643: 166,
#  644: 167,
#  649: 168,
#  652: 169,
#  655: 170,
#  656: 171,
#  662: 172,
#  664: 173,
#  673: 174,
#  674: 175,
#  680: 176,
#  681: 177,
#  683: 178,
#  686: 179,
#  689: 180,
#  694: 181,
#  699: 182,
#  711: 183,
#  713: 184,
#  714: 185,
#  716: 186,
#  719: 187,
#  725: 188,
#  728: 189,
#  730: 190,
#  731: 191,
#  732: 192,
#  734: 193,
#  745: 194,
#  746: 195,
#  748: 196,
#  753: 197,
#  760: 198,
#  764: 199,
#  770: 200,
#  774: 201,
#  776: 202,
#  778: 203,
#  779: 204,
#  780: 205,
#  781: 206,
#  783: 207,
#  785: 208,
#  791: 209,
#  792: 210,
#  793: 211,
#  794: 212,
#  807: 213,
#  815: 214,
#  819: 215,
#  820: 216,
#  822: 217,
#  823: 218,
#  830: 219,
#  831: 220,
#  836: 221,
#  841: 222,
#  842: 223,
#  848: 224,
#  849: 225,
#  851: 226,
#  853: 227,
#  858: 228,
#  859: 229,
#  860: 230,
#  864: 231,
#  865: 232,
#  866: 233,
#  869: 234,
#  870: 235,
#  871: 236,
#  876: 237,
#  882: 238,
#  888: 239,
#  889: 240,
#  890: 241,
#  891: 242,
#  894: 243,
#  897: 244,
#  899: 245,
#  901: 246,
#  902: 247,
#  911: 248,
#  912: 249,
#  915: 250,
#  917: 251,
#  921: 252,
#  925: 253,
#  927: 254,
#  932: 255,
#  934: 256,
#  936: 257,
#  938: 258,
#  943: 259,
#  944: 260,
#  945: 261,
#  948: 262,
#  950: 263,
#  953: 264,
#  965: 265,
#  967: 266,
#  969: 267,
#  970: 268,
#  974: 269,
#  976: 270,
#  979: 271,
#  984: 272,
#  985: 273,
#  986: 274,
#  989: 275,
#  994: 276,
#  995: 277,
#  997: 278,
#  998: 279,
#  1000: 280,
#  1002: 281,
#  1004: 282,
#  1008: 283,
#  1010: 284,
#  1016: 285,
#  1021: 286,
#  1023: 287,
#  1025: 288,
#  1036: 289,
#  1043: 290,
#  1045: 291,
#  1046: 292,
#  1047: 293,
#  1048: 294,
#  1049: 295,
#  1063: 296,
#  1066: 297,
#  1073: 298,
#  1079: 299,
#  1091: 300,
#  1092: 301,
#  1094: 302,
#  1096: 303,
#  1101: 304,
#  1107: 305,
#  1113: 306,
#  1115: 307,
#  1116: 308,
#  1117: 309,
#  1127: 310,
#  1128: 311,
#  1133: 312,
#  1139: 313,
#  1150: 314,
#  1162: 315,
#  1167: 316,
#  1170: 317,
#  1173: 318,
#  1177: 319,
#  1179: 320,
#  1184: 321,
#  1185: 322,
#  1187: 323,
#  1192: 324,
#  1197: 325,
#  1203: 326,
#  1205: 327,
#  1207: 328,
#  1209: 329,
#  1210: 330,
#  1218: 331,
#  1220: 332,
#  1227: 333,
#  1231: 334,
#  1235: 335,
#  1239: 336,
#  1244: 337,
#  1245: 338,
#  1246: 339,
#  1247: 340,
#  1248: 341,
#  1249: 342,
#  1250: 343,
#  1259: 344,
#  1264: 345,
#  1266: 346,
#  1273: 347,
#  1286: 348,
#  1289: 349,
#  1296: 350,
#  1297: 351,
#  1309: 352,
#  1310: 353,
#  1316: 354,
#  1329: 355,
#  1334: 356,
#  1347: 357,
#  1348: 358,
#  1353: 359,
#  1356: 360,
#  1357: 361,
#  1358: 362,
#  1365: 363,
#  1367: 364,
#  1371: 365,
#  1373: 366,
#  1374: 367,
#  1392: 368,
#  1393: 369,
#  1395: 370,
#  1396: 371,
#  1397: 372,
#  1400: 373,
#  1404: 374,
#  1407: 375,
#  1409: 376,
#  1412: 377,
#  1417: 378,
#  1420: 379,
#  1421: 380,
#  1430: 381,
#  1433: 382,
#  1437: 383,
#  1439: 384,
#  1440: 385,
#  1443: 386,
#  1450: 387,
#  1453: 388,
#  1463: 389,
#  1469: 390,
#  1470: 391,
#  1483: 392,
#  1487: 393,
#  1488: 394,
#  1491: 395,
#  1493: 396,
#  1495: 397,
#  1496: 398,
#  1498: 399,
#  1504: 400,
#  1514: 401,
#  1523: 402,
#  1529: 403,
#  1552: 404,
#  1558: 405,
#  1561: 406,
#  1563: 407,
#  1565: 408,
#  1567: 409,
#  1568: 410,
#  1570: 411,
#  1571: 412,
#  1581: 413,
#  1582: 414,
#  1596: 415,
#  1599: 416,
#  1601: 417,
#  1606: 418,
#  1609: 419,
#  1611: 420,
#  1612: 421,
#  1616: 422,
#  1619: 423,
#  1626: 424,
#  1627: 425,
#  1629: 426,
#  1630: 427,
#  1631: 428,
#  1640: 429,
#  1641: 430,
#  1650: 431,
#  1659: 432,
#  1664: 433,
#  1665: 434,
#  1667: 435,
#  1671: 436,
#  1679: 437,
#  1682: 438,
#  1690: 439,
#  1694: 440,
#  1697: 441,
#  1708: 442,
#  1710: 443,
#  1720: 444,
#  1723: 445,
#  1731: 446,
#  1733: 447,
#  1739: 448,
#  1747: 449,
#  1749: 450,
#  1750: 451,
#  1752: 452,
#  1755: 453,
#  1756: 454,
#  1760: 455,
#  1766: 456,
#  1773: 457,
#  1775: 458,
#  1783: 459,
#  1792: 460,
#  1795: 461,
#  1796: 462,
#  1800: 463,
#  1801: 464,
#  1803: 465,
#  1806: 466,
#  1812: 467,
#  1813: 468,
#  1817: 469,
#  1820: 470,
#  1822: 471,
#  1833: 472,
#  1840: 473,
#  1850: 474,
#  1858: 475,
#  1864: 476,
#  1870: 477,
#  1874: 478,
#  1878: 479,
#  1879: 480,
#  1883: 481,
#  1886: 482,
#  1891: 483,
#  1893: 484,
#  1894: 485,
#  1895: 486,
#  1897: 487,
#  1900: 488,
#  1902: 489,
#  1910: 490,
#  1911: 491,
#  1924: 492,
#  1925: 493,
#  1930: 494,
#  1938: 495,
#  1941: 496,
#  1946: 497,
#  1947: 498,
#  1950: 499,
#  1957: 500,
#  1961: 501,
#  1962: 502,
#  1963: 503,
#  1967: 504,
#  1973: 505,
#  1975: 506,
#  1989: 507,
#  1996: 508,
#  2002: 509,
#  2003: 510,
#  2006: 511,
#  2009: 512,
#  2018: 513,
#  2021: 514,
#  2030: 515,
#  2033: 516,
#  2037: 517,
#  2043: 518,
#  2046: 519,
#  2047: 520,
#  2058: 521,
#  2059: 522,
#  2060: 523,
#  2061: 524,
#  2063: 525,
#  2073: 526,
#  2079: 527,
#  2088: 528,
#  2092: 529,
#  2095: 530,
#  2098: 531,
#  2100: 532,
#  2109: 533,
#  2111: 534,
#  2123: 535,
#  2132: 536,
#  2135: 537,
#  2136: 538,
#  2143: 539,
#  2145: 540,
#  2158: 541,
#  2159: 542,
#  2161: 543,
#  2162: 544,
#  2169: 545,
#  2170: 546,
#  2174: 547,
#  2179: 548,
#  2180: 549,
#  2189: 550,
#  2191: 551,
#  2194: 552,
#  2204: 553,
#  2209: 554,
#  2219: 555,
#  2220: 556,
#  2222: 557,
#  2224: 558,
#  2225: 559,
#  2233: 560,
#  2235: 561,
#  2236: 562,
#  2237: 563,
#  2239: 564,
#  2251: 565,
#  2261: 566,
#  2262: 567,
#  2280: 568,
#  2281: 569,
#  2286: 570,
#  2292: 571,
#  2300: 572,
#  2302: 573,
#  2303: 574,
#  2304: 575,
#  2307: 576,
#  2310: 577,
#  2316: 578,
#  2317: 579,
#  2320: 580,
#  2326: 581,
#  2327: 582,
#  2337: 583,
#  2339: 584,
#  2345: 585,
#  2346: 586,
#  2349: 587,
#  2353: 588,
#  2355: 589,
#  2356: 590,
#  2362: 591,
#  2365: 592,
#  2367: 593,
#  2371: 594,
#  2372: 595,
#  2373: 596,
#  2381: 597,
#  2382: 598,
#  2388: 599,
#  2389: 600,
#  2400: 601,
#  2402: 602,
#  2410: 603,
#  2411: 604,
#  2414: 605,
#  2423: 606,
#  2424: 607,
#  2437: 608,
#  2441: 609,
#  2448: 610,
#  2450: 611,
#  2454: 612,
#  2461: 613,
#  2462: 614,
#  2463: 615,
#  2464: 616,
#  2465: 617,
#  2468: 618,
#  2469: 619,
#  2471: 620,
#  2476: 621,
#  2478: 622,
#  2480: 623,
#  2483: 624,
#  2484: 625,
#  2493: 626,
#  2507: 627,
#  2509: 628,
#  2510: 629,
#  2513: 630,
#  2518: 631,
#  2520: 632,
#  2523: 633,
#  2531: 634,
#  2535: 635,
#  2543: 636,
#  2544: 637,
#  2546: 638,
#  2547: 639,
#  2557: 640,
#  2559: 641,
#  2563: 642,
#  2569: 643,
#  2572: 644,
#  2576: 645,
#  2586: 646,
#  2595: 647,
#  2600: 648,
#  2601: 649,
#  2604: 650,
#  2605: 651,
#  2608: 652,
#  2609: 653,
#  2610: 654,
#  2611: 655,
#  2613: 656,
#  2615: 657,
#  2616: 658,
#  2622: 659,
#  2638: 660,
#  2640: 661,
#  2641: 662,
#  2644: 663,
#  2650: 664,
#  2653: 665,
#  2656: 666,
#  2662: 667,
#  2664: 668,
#  2666: 669,
#  2672: 670,
#  2674: 671,
#  2675: 672,
#  2687: 673,
#  2691: 674,
#  2697: 675,
#  2703: 676,
#  2704: 677,
#  2713: 678,
#  2715: 679,
#  2720: 680,
#  2721: 681,
#  2722: 682,
#  2727: 683,
#  2731: 684,
#  2735: 685,
#  2739: 686,
#  2741: 687,
#  2744: 688,
#  2745: 689,
#  2748: 690,
#  2754: 691,
#  2764: 692,
#  2766: 693,
#  2768: 694,
#  2771: 695,
#  2776: 696,
#  2787: 697,
#  2791: 698,
#  2796: 699,
#  2804: 700,
#  2805: 701,
#  2814: 702,
#  2820: 703,
#  2822: 704,
#  2824: 705,
#  2831: 706,
#  2832: 707,
#  2840: 708,
#  2845: 709,
#  2852: 710,
#  2855: 711,
#  2856: 712,
#  2860: 713,
#  2865: 714,
#  2866: 715,
#  2868: 716,
#  2871: 717,
#  2874: 718,
#  2876: 719,
#  2881: 720,
#  2885: 721,
#  2891: 722,
#  2892: 723,
#  2901: 724,
#  2902: 725,
#  2913: 726,
#  2919: 727,
#  2924: 728,
#  2938: 729,
#  2941: 730,
#  2950: 731,
#  2952: 732,
#  2953: 733,
#  2969: 734,
#  2970: 735,
#  2972: 736,
#  2974: 737,
#  2976: 738,
#  2980: 739,
#  2982: 740,
#  2987: 741,
#  2992: 742,
#  2993: 743,
#  2997: 744,
#  2998: 745,
#  3001: 746,
#  3004: 747,
#  3005: 748,
#  3008: 749,
#  3015: 750,
#  3018: 751,
#  3021: 752,
#  3051: 753,
#  3054: 754,
#  3055: 755,
#  3061: 756,
#  3071: 757,
#  3079: 758,
#  3085: 759,
#  3101: 760,
#  3102: 761,
#  3105: 762,
#  3106: 763,
#  3110: 764,
#  3118: 765,
#  3120: 766,
#  3123: 767,
#  3127: 768,
#  3136: 769,
#  3139: 770,
#  3142: 771,
#  3144: 772,
#  3145: 773,
#  3148: 774,
#  3151: 775,
#  3154: 776,
#  3160: 777,
#  3163: 778,
#  3164: 779,
#  3165: 780,
#  3168: 781,
#  3171: 782,
#  3174: 783,
#  3179: 784,
#  3185: 785,
#  3187: 786,
#  3191: 787,
#  3198: 788,
#  3203: 789,
#  3210: 790,
#  3213: 791,
#  3214: 792,
#  3223: 793,
#  3224: 794,
#  3227: 795,
#  3229: 796,
#  3230: 797,
#  3232: 798,
#  3235: 799,
#  3236: 800,
#  3249: 801,
#  3257: 802,
#  3260: 803,
#  3266: 804,
#  3268: 805,
#  3275: 806,
#  3276: 807,
#  3278: 808,
#  3284: 809,
#  3286: 810,
#  3287: 811,
#  3291: 812,
#  3297: 813,
#  3298: 814,
#  3303: 815,
#  3308: 816,
#  3311: 817,
#  3312: 818,
#  3313: 819,
#  3315: 820,
#  3329: 821,
#  3330: 822,
#  3331: 823,
#  3332: 824,
#  3333: 825,
#  3334: 826,
#  3336: 827,
#  3337: 828,
#  3354: 829,
#  3358: 830,
#  3363: 831,
#  3369: 832,
#  3376: 833,
#  3381: 834,
#  3382: 835,
#  3388: 836,
#  3393: 837,
#  3395: 838,
#  3396: 839,
#  3399: 840,
#  3400: 841,
#  3405: 842,
#  3409: 843,
#  3411: 844,
#  3423: 845,
#  3431: 846,
#  3432: 847,
#  3433: 848,
#  3434: 849,
#  3436: 850,
#  3437: 851,
#  3451: 852,
#  3454: 853,
#  3458: 854,
#  3462: 855,
#  3466: 856,
#  3470: 857,
#  3473: 858,
#  3476: 859,
#  3479: 860,
#  3480: 861,
#  3481: 862,
#  3483: 863,
#  3493: 864,
#  3497: 865,
#  3499: 866,
#  3502: 867,
#  3508: 868,
#  3509: 869,
#  3517: 870,
#  3522: 871,
#  3524: 872,
#  3528: 873,
#  3531: 874,
#  3532: 875,
#  3533: 876,
#  3539: 877,
#  3541: 878,
#  3547: 879,
#  3558: 880,
#  3578: 881,
#  3581: 882,
#  3582: 883,
#  3588: 884,
#  3589: 885,
#  3600: 886,
#  3601: 887,
#  3602: 888,
#  3604: 889,
#  3607: 890,
#  3608: 891,
#  3612: 892,
#  3620: 893,
#  3621: 894,
#  3623: 895,
#  3625: 896,
#  3626: 897,
#  3632: 898,
#  3633: 899,
#  3642: 900,
#  3644: 901,
#  3645: 902,
#  3646: 903,
#  3647: 904,
#  3651: 905,
#  3652: 906,
#  3653: 907,
#  3655: 908,
#  3665: 909,
#  3681: 910,
#  3688: 911,
#  3694: 912,
#  3697: 913,
#  3701: 914,
#  3702: 915,
#  3711: 916,
#  3714: 917,
#  3715: 918,
#  3724: 919,
#  3725: 920,
#  3730: 921,
#  3733: 922,
#  3737: 923,
#  3741: 924,
#  3743: 925,
#  3749: 926,
#  3755: 927,
#  3756: 928,
#  3758: 929,
#  3775: 930,
#  3784: 931,
#  3785: 932,
#  3793: 933,
#  3811: 934,
#  3812: 935,
#  3814: 936,
#  3816: 937,
#  3819: 938,
#  3824: 939,
#  3825: 940,
#  3827: 941,
#  3828: 942,
#  3829: 943,
#  3838: 944,
#  3845: 945,
#  3850: 946,
#  3858: 947,
#  3862: 948,
#  3869: 949,
#  3882: 950,
#  3890: 951,
#  3892: 952,
#  3894: 953,
#  3896: 954,
#  3897: 955,
#  3899: 956,
#  3901: 957,
#  3907: 958,
#  3914: 959,
#  3916: 960,
#  3917: 961,
#  3922: 962,
#  3923: 963,
#  3926: 964,
#  3928: 965,
#  3929: 966,
#  3931: 967,
#  3932: 968,
#  3933: 969,
#  3934: 970,
#  3940: 971,
#  3941: 972,
#  3944: 973,
#  3945: 974,
#  3949: 975,
#  3953: 976,
#  3954: 977,
#  3965: 978,
#  3966: 979,
#  3968: 980,
#  3972: 981,
#  3979: 982,
#  3982: 983,
#  3999: 984,
#  4004: 985,
#  4007: 986,
#  4009: 987,
#  4011: 988,
#  4016: 989,
#  4018: 990,
#  4024: 991,
#  4027: 992,
#  4033: 993,
#  4036: 994,
#  4041: 995,
#  4052: 996,
#  4055: 997,
#  4056: 998,
#  4058: 999,
#  ...}

# %%
user2user_decoded = {i : x for i , x in enumerate(user_ids)}
rating_df["user"] = rating_df["user_id"].map(user2user_encoded)

# %%
rating_df.sample(100)
# Out:
#          user_id  anime_id  rating  user
# 6470556    21200       514       9  5411
# 6526106    21377     30806       0  5462
# 5868831    19246     37569       7  4923
# 2141986     7215     32866       6  1815
# 6802820    22310      6880       5  5680
# ...          ...       ...     ...   ...
# 8850650    28902     37980       5  7400
# 5601822    18369     39326       7  4683
# 4167299    13746        24       0  3502
# 8023720    26188      1195       7  6706
# 5100161    16800     11499       7  4277
#
# [100 rows x 4 columns]

# %%
len(rating_df)
# Out:
# 5866296

# %%
min_rating =min(rating_df["rating"])

# %%
max_rating =max(rating_df["rating"])

# %%
max_rating
# Out:
# 10

# %%
avg_rating =np.mean(rating_df["rating"])

# %%
avg_rating
# Out:
# np.float64(4.096097435247045)

# %%
rating_df["rating"] = rating_df["rating"].apply(lambda x: (x-min_rating)/(max_rating-min_rating)).values.astype(np.float64)

# %%
rating_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
rating_df.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# user        0
# dtype: int64

# %%
user_ids = rating_df["user_id"].unique().tolist()
user2user_encoded = {x : i for i , x in enumerate(user_ids)}
user2user_decoded = {i : x for i , x in enumerate(user_ids)}
rating_df["user"] = rating_df["user_id"].map(user2user_encoded)

# %%
n_users = len(user2user_encoded)

# %%
n_users
# Out:
# 7528

# %%
## 11054 : 12  -> user2user encoded
## 12 : 11054 ---> usser2userdecocded

# %%
anime_ids = rating_df["anime_id"].unique().tolist()
anime2anime_encoded = {x : i for i , x in enumerate(anime_ids)}
anime2anime_decoded = {i : x for i , x in enumerate(anime_ids)}
rating_df["anime"] = rating_df["anime_id"].map(anime2anime_encoded)

# %%
n_anime = len(anime2anime_encoded)

# %%
n_anime
# Out:
# 17554

# %%
rating_df = rating_df.sample(frac=1,random_state=43).reset_index(drop=True)

# %%
rating_df.head(2)
# Out:
#    user_id  anime_id  rating  user  anime
# 0     6624     23321     0.8  1658   1193
# 1     6359     12549     0.0  1603   1302

# %%
X = rating_df[["user","anime"]].values
y = rating_df["rating"]

# %%
test_size = 1000
train_indices = rating_df.shape[0] - test_size

# %%
X_train , X_test , y_train , y_test = (
    X[:train_indices],
    X[train_indices :],
    y[:train_indices],
    y[train_indices:],
)

# %%
len(X_train)
# Out:
# 5865296

# %%
len(X_test)
# Out:
# 1000

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train_array = [X_train[: , 0] , X_train[: ,1]]
X_test_array = [X_test[: , 0] , X_test[: ,1]]

# %%
type(X_test_array)
# Out:
# list

# %%
type(X_test_array[0])
# Out:
# numpy.ndarray

# %% [markdown]
# #### MODEL ARCHITECTURE

# %%
def RecommenderNet():
    embedding_size =128

    user = Input(name="user",shape=[1])

    user_embedding = Embedding(name="user_embedding",input_dim=n_users,output_dim=embedding_size)(user)

    anime = Input(name="anime",shape=[1])

    anime_embedding = Embedding(name="anime_embedding",input_dim=n_anime,output_dim=embedding_size)(anime)

    x = Dot(name="dot_product" , normalize=True , axes=2)([user_embedding,anime_embedding])

    x = Flatten()(x)

    x = Dense(1,kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation("sigmoid")(x)

    model = Model(inputs=[user,anime], outputs=x)
    model.compile(loss="binary_crossentropy",metrics=["mae","mse"],optimizer='Adam')
    return model

# %%
model = RecommenderNet()

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ user (InputLayer)   │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ anime (InputLayer)  │ (None, 1)         │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ user_embedding      │ (None, 1, 128)    │    963,584 │ user[0][0]        │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ anime_embedding     │ (None, 1, 128)    │  2,246,912 │ anime[0][0]       │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot_product (Dot)   │ (None, 1, 1)      │          0 │ user_embedding[0… │
# │                     │                   │            │ anime_embedding[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 1)         │          0 │ dot_product[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │          2 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1)         │          4 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1)         │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,210,502 (12.25 MB)
#  Trainable params: 3,210,500 (12.25 MB)
#  Non-trainable params: 2 (8.00 B)

# %%
start_lr = 0.00001
min_lr = 0.0001
max_lr = 0.00005
batch_size = 10000

ramup_epochs = 5
sustain_epochs = 0
exp_decay = 0.8

def lrfn(epoch):
    if epoch<ramup_epochs:
        return (max_lr-start_lr)/ramup_epochs*epoch + start_lr
    elif epoch<ramup_epochs+sustain_epochs:
        return max_lr
    else:
        return (max_lr-min_lr) * exp_decay ** (epoch-ramup_epochs-sustain_epochs)+min_lr

# %%
lr_callback = LearningRateScheduler(lambda epoch:lrfn(epoch) , verbose=0)
checkpoint_filepath = './weights.weights.h5'

model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath,save_weights_only=True,monitor="val_loss",mode="min",save_best_only=True)

early_stopping = EarlyStopping(patience=3,monitor="val_loss",mode="min",restore_best_weights=True)

# %%
my_callbacks = [model_checkpoint,lr_callback,early_stopping]

# %%
history = model.fit(
    x=X_train_array,
    y=y_train,
    batch_size=batch_size,
    epochs=20,
    verbose=1,
    validation_data = (X_test_array,y_test),
    callbacks=my_callbacks
)
# Out:
# Epoch 1/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 52s 84ms/step - loss: 0.7901 - mae: 0.3806 - mse: 0.1943 - val_loss: 0.7657 - val_mae: 0.3798 - val_mse: 0.1872 - learning_rate: 1.0000e-05
# Epoch 2/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 50s 84ms/step - loss: 0.7853 - mae: 0.3791 - mse: 0.1924 - val_loss: 0.7883 - val_mae: 0.3844 - val_mse: 0.1950 - learning_rate: 1.8000e-05
# Epoch 3/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 50s 85ms/step - loss: 0.7772 - mae: 0.3763 - mse: 0.1892 - val_loss: 0.7834 - val_mae: 0.3831 - val_mse: 0.1931 - learning_rate: 2.6000e-05
# Epoch 4/20
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 50s 85ms/step - loss: 0.7654 - mae: 0.3719 - mse: 0.1845 - val_loss: 0.7750 - val_mae: 0.3803 - val_mse: 0.1899 - learning_rate: 3.4000e-05

# %%
model.load_weights(checkpoint_filepath)

# %%
metrics = ["loss", "mae", "mse"]

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, len(metrics) * 4))

for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(history.history[metric][0:-2], marker="o", label=f"train {metric}")
    ax.plot(history.history[f"val_{metric}"][0:-2], marker="o", label=f"test {metric}")
    ax.set_title(f"Model {metric.capitalize()}")
    ax.set_ylabel(metric.capitalize())
    ax.set_xlabel("Epoch")
    ax.legend(loc="upper left")
    ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 4
#       1 metrics = ["loss", "mae", "mse"]
#       3 # Create subplots
# ----> 4 fig, axes = plt.subplots(len(metrics), 1, figsize=(8, len(metrics) * 4))
#       6 for i, metric in enumerate(metrics):
#       7     ax = axes[i]
#
# NameError: name 'plt' is not defined

# %%
def extract_weights(name,model):
    weight_layer = model.get_layer(name)
    weights = weight_layer.get_weights()[0]
    weights = weights/np.linalg.norm(weights,axis=1).reshape((-1,1))
    return weights

# %%
anime_weights = extract_weights("anime_embedding",model)

# %%
user_weights = extract_weights("user_embedding",model)

# %% [markdown]
# #### READING ANIME.CSV

# %%
df = pd.read_csv(INPUT_DIR+"/anime.csv",low_memory=True)
df.head(2)
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
#
#                                             Genres            English name  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1            Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
#
#     Japanese name   Type Episodes                        Aired    Premiered  \
# 0       カウボーイビバップ     TV       26  Apr 3, 1998 to Apr 24, 1999  Spring 1998
# 1  カウボーイビバップ 天国の扉  Movie        1                  Sep 1, 2001      Unknown
#
#    ...  Score-10   Score-9   Score-8  Score-7  Score-6 Score-5 Score-4  \
# 0  ...  229170.0  182126.0  131625.0  62330.0  20688.0  8904.0  3184.0
# 1  ...   30043.0   49201.0   49505.0  22632.0   5805.0  1877.0   577.0
#
#    Score-3  Score-2  Score-1
# 0   1357.0    741.0   1580.0
# 1    221.0    109.0    379.0
#
# [2 rows x 35 columns]

# %%
df = df.replace("Unknown",np.nan)

# %%
def getAnimeName(anime_id):
    try:
        name = df[df.anime_id == anime_id].eng_version.values[0]
        if name is np.nan:
            name = df[df.anime_id == anime_id].Name.values[0]
    except:
        print("Error")
    return name

# %%
df["anime_id"] = df["MAL_ID"]
df["eng_version"] = df["English name"]
df["eng_version"] = df.anime_id.apply(lambda x:getAnimeName(x))

# %%
getAnimeName(6702)
# Out:
# 'Fairy Tail'

# %%
df.sort_values(by=["Score"],
               inplace=True,
               ascending=False,
               kind="quicksort",
               na_position="last")

# %%
df.columns
# Out:
# Index(['MAL_ID', 'Name', 'Score', 'Genres', 'English name', 'Japanese name',
#        'Type', 'Episodes', 'Aired', 'Premiered', 'Producers', 'Licensors',
#        'Studios', 'Source', 'Duration', 'Rating', 'Ranked', 'Popularity',
#        'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped',
#        'Plan to Watch', 'Score-10', 'Score-9', 'Score-8', 'Score-7', 'Score-6',
#        'Score-5', 'Score-4', 'Score-3', 'Score-2', 'Score-1', 'anime_id',
#        'eng_version'],
#       dtype='object')

# %%
df = df[["anime_id" , "eng_version","Score","Genres","Episodes","Type","Premiered","Members"]]

# %%
df.head()
# Out:
#        anime_id                      eng_version Score  \
# 3971       5114  Fullmetal Alchemist:Brotherhood  9.19
# 15926     40028     Attack on Titan Final Season  9.17
# 5683       9253                      Steins;Gate  9.11
# 14963     38524  Attack on Titan Season 3 Part 2   9.1
# 9913      28977                 Gintama Season 4   9.1
#
#                                                   Genres Episodes Type  \
# 3971   Action, Military, Adventure, Comedy, Drama, Ma...       64   TV
# 15926  Action, Military, Mystery, Super Power, Drama,...       16   TV
# 5683                                    Thriller, Sci-Fi       24   TV
# 14963  Action, Drama, Fantasy, Military, Mystery, Sho...       10   TV
# 9913   Action, Comedy, Historical, Parody, Samurai, S...       51   TV
#
#          Premiered  Members
# 3971   Spring 2009  2248456
# 15926  Winter 2021   733260
# 5683   Spring 2011  1771162
# 14963  Spring 2019  1073626
# 9913   Spring 2015   404121

# %%
def getAnimeFrame(anime,df):
    if isinstance(anime,int):
        return df[df.anime_id == anime]
    if isinstance(anime,str):
        return df[df.eng_version == anime]

# %%
getAnimeFrame('Attack on Titan Final Season' , df)
# Out:
#        anime_id                   eng_version Score  \
# 15926     40028  Attack on Titan Final Season  9.17
#
#                                                   Genres Episodes Type  \
# 15926  Action, Military, Mystery, Super Power, Drama,...       16   TV
#
#          Premiered  Members
# 15926  Winter 2021   733260

# %%
getAnimeFrame('Attack on Titan Final Season' , df).anime_id.values[0]
# Out:
# np.int64(40028)

# %%
anime2anime_encoded.get(40028)
# Out:
# 1666

# %%
weights = anime_weights

# %%
# Compute the similarity distances
dists = np.dot(weights, weights[1666])  # Ensure weights[encoded_index] is a 1D array
dists[17228]
# Out:
# np.float32(0.3113764)

# %%
sorted_dists = np.argsort(dists)
sorted_dists
# Out:
# array([10430, 12053, 12738, ..., 11201, 15462,  1666], shape=(17554,))

# %%
closest = sorted_dists[-5:]

# %%
closest
# Out:
# array([17228,  1532, 11201, 15462,  1666])

# %%
SimilarityArr = []
for close in closest:
    decoded_id = anime2anime_decoded.get(close)

    anime_frame = getAnimeFrame(decoded_id, df)
    print(anime_frame)
    anime_name = anime_frame.eng_version.values[0]
    print(anime_name)
    genre = anime_frame.Genres.values[0]
    similarity = dists[close]
    print(similarity)

    SimilarityArr.append({
            "anime_id": decoded_id,
            "name": anime_name,
            "similarity": similarity,
            "genre": genre,
    })
# Out:
#        anime_id eng_version Score    Genres Episodes   Type Premiered  Members
# 15185     38868   Blow Up 2   NaN  Dementia        1  Movie       NaN       70
# Blow Up 2
# 0.3113764
#        anime_id          eng_version Score                         Genres  \
# 14055     37105  Grand Blue Dreaming  8.41  Slice of Life, Comedy, Seinen
#
#       Episodes Type    Premiered  Members
# 14055       12   TV  Summer 2018   421403
# Grand Blue Dreaming
# 0.316614
#       anime_id                  eng_version Score  \
# 2104      2301  Tekkaman Blade:Missing Link  6.05
#
#                               Genres Episodes Type Premiered  Members
# 2104  Action, Mecha, Sci-Fi, Shounen        1  OVA       NaN     1674
# Tekkaman Blade:Missing Link
# 0.31672096
#       anime_id               eng_version Score Genres Episodes   Type  \
# 5697      9292  Kiki to Lala no Aoi Tori   NaN   Kids        1  Movie
#
#      Premiered  Members
# 5697       NaN      329
# Kiki to Lala no Aoi Tori
# 0.35014546
#        anime_id                   eng_version Score  \
# 15926     40028  Attack on Titan Final Season  9.17
#
#                                                   Genres Episodes Type  \
# 15926  Action, Military, Mystery, Super Power, Drama,...       16   TV
#
#          Premiered  Members
# 15926  Winter 2021   733260
# Attack on Titan Final Season
# 0.9999999

# %% [markdown]
# #### ANIME_WITH_SYNOPSIS.CSV

# %%
cols = ["MAL_ID","Name","Genres","sypnopsis"]

# %%
synopsis_df = pd.read_csv(INPUT_DIR+"/anime_with_synopsis.csv",usecols=cols)

# %%
synopsis_df.head(1)
# Out:
#    MAL_ID          Name                                           Genres  \
# 0       1  Cowboy Bebop  Action, Adventure, Comedy, Drama, Sci-Fi, Space
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  sypnopsis
# 0  In the year 2071, humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet Earth behind. The Inter Solar System Police attempts to keep peace in the galaxy, aided in part by outlaw bounty hunters, referred to as "Cowboys." The ragtag team aboard the spaceship Bebop are two such individuals. Mellow and carefree Spike Spiegel is balanced by his boisterous, pragmatic partner Jet Black as the pair makes a living chasing bounties and collecting rewards. Thrown off course by the addition of new members that they meet in their travels—Ein, a genetically engineered, highly intelligent Welsh Corgi; femme fatale Faye Valentine, an enigmatic trickster with memory loss; and the strange computer whiz kid Edward Wong—the crew embarks on thrilling adventures that unravel each member's dark and mysterious past little by little. Well-balanced with high density action and light-hearted comedy, Cowboy Bebop is a space Western classic and an homage to the smooth and improvised music it is named after.

# %%
synopsis_df.columns
# Out:
# Index(['MAL_ID', 'Name', 'Genres', 'sypnopsis'], dtype='object')

# %%
def getSynopsis(anime,synopsis_df):
    if isinstance(anime,int):
        return synopsis_df[synopsis_df.MAL_ID == anime].sypnopsis.values[0]
    if isinstance(anime,str):
        return synopsis_df[synopsis_df.Name == anime].sypnopsis.values[0]

# %%
getSynopsis(40028 , synopsis_df)
# Out:
# "Gabi Braun and Falco Grice have been training their entire lives to inherit one of the seven titans under Marley's control and aid their nation in eradicating the Eldians on Paradis. However, just as all seems well for the two cadets, their peace is suddenly shaken by the arrival of Eren Yeager and the remaining members of the Survey Corps. Having finally reached the Yeager family basement and learned about the dark history surrounding the titans, the Survey Corps has at long last found the answer they so desperately fought to uncover. With the truth now in their hands, the group set out for the world beyond the walls. In Shingeki no Kyojin: The Final Season , two utterly different worlds collide as each party pursues its own agenda in the long-awaited conclusion to Paradis' fight for freedom."

# %%
getSynopsis("Steins;Gate",synopsis_df)
# Out:
# 'The self-proclaimed mad scientist Rintarou Okabe rents out a room in a rickety old building in Akihabara, where he indulges himself in his hobby of inventing prospective "future gadgets" with fellow lab members: Mayuri Shiina, his air-headed childhood friend, and Hashida Itaru, a perverted hacker nicknamed "Daru." The three pass the time by tinkering with their most promising contraption yet, a machine dubbed the "Phone Microwave," which performs the strange function of morphing bananas into piles of green gel. Though miraculous in itself, the phenomenon doesn\'t provide anything concrete in Okabe\'s search for a scientific breakthrough; that is, until the lab members are spurred into action by a string of mysterious happenings before stumbling upon an unexpected success—the Phone Microwave can send emails to the past, altering the flow of history. Adapted from the critically acclaimed visual novel by 5pb. and Nitroplus, Steins;Gate takes Okabe through the depths of scientific theory and practicality. Forced across the diverging threads of past and present, Okabe must shoulder the burdens that come with holding the key to the realm of time.'

# %% [markdown]
# ### CONTENT/ITEM BASED RECOMMENDATION

# %%
pd.set_option("max_colwidth",None)

# %%
def find_similar_animes(name, anime_weights, anime2anime_encoded, anime2anime_decoded, df, synopsis_df, n=10, return_dist=False, neg=False):
    # Get the anime_id for the given name
    index = getAnimeFrame(name, df).anime_id.values[0]
    encoded_index = anime2anime_encoded.get(index)

    if encoded_index is None:
        raise ValueError(f"Encoded index not found for anime ID: {index}")

    weights = anime_weights

    # Compute the similarity distances
    dists = np.dot(weights, weights[encoded_index])  # Ensure weights[encoded_index] is a 1D array
    sorted_dists = np.argsort(dists)

    n = n + 1

    # Select closest or farthest based on 'neg' flag
    if neg:
        closest = sorted_dists[:n]
    else:
        closest = sorted_dists[-n:]

    # Return distances and closest indices if requested
    if return_dist:
        return dists, closest

    # Build the similarity array
    SimilarityArr = []
    for close in closest:
        decoded_id = anime2anime_decoded.get(close)
       

       
        anime_frame = getAnimeFrame(decoded_id, df)

        anime_name = anime_frame.eng_version.values[0]
        genre = anime_frame.Genres.values[0]
        similarity = dists[close]
   

        SimilarityArr.append({
            "anime_id": decoded_id,
            "name": anime_name,
            "similarity": similarity,
            "genre": genre,
        })
       

    # Create a DataFrame with results and sort by similarity
    Frame = pd.DataFrame(SimilarityArr).sort_values(by="similarity", ascending=False)
    return Frame[Frame.anime_id != index].drop(['anime_id'], axis=1)

# %%
find_similar_animes(
    "Steins;Gate",
    anime_weights,
    anime2anime_encoded,
    anime2anime_decoded,
    df,
    synopsis_df,
)
# Out:
#                                     name  similarity  \
# 9                        Minna Tomodachi    0.345735
# 8        Kimi ni Todoke:From Me To You 2    0.325021
# 7                 Yume Hakonda Randoseru    0.313089
# 6                                 Broots    0.310526
# 5                     Ojiichan no Tomato    0.307859
# 4                   What Is Not Romance?    0.303482
# 3                      Yume no Tochuu de    0.298758
# 2          Luo Xiao Hei Zhan Ji: Fan Wai    0.296493
# 1  Lupin III Episode 0:The First Contact    0.292195
# 0          Charamaru-kun to Dokumaru-kun    0.289313
#
#                                            genre
# 9                          Comedy, Fantasy, Kids
# 8  Slice of Life, Drama, Romance, School, Shoujo
# 7                     Music, Slice of Life, Kids
# 6                                  Sci-Fi, Mecha
# 5                                    Drama, Kids
# 4                                          Drama
# 3                                    Kids, Music
# 2                  Comedy, Music, Parody, School
# 1     Action, Adventure, Mystery, Comedy, Seinen
# 0                              Kids, Super Power

# %% [markdown]
# ### USER BASED RECOMMENDATION

# %%
def find_similar_users(item_input , user_weights , user2user_encoded , user2user_decoded, n=10 , return_dist=False,neg=False):
    try:
        index=item_input
        encoded_index = user2user_encoded.get(index)

        weights = user_weights

        dists = np.dot(weights,weights[encoded_index])
        sorted_dists = np.argsort(dists)

        n=n+1

        if neg:
            closest = sorted_dists[:n]
        else:
            closest = sorted_dists[-n:]
            

        if return_dist:
            return dists,closest
        
        SimilarityArr = []

        for close in closest:
            similarity = dists[close]

            if isinstance(item_input,int):
                decoded_id = user2user_decoded.get(close)
                SimilarityArr.append({
                    "similar_users" : decoded_id,
                    "similarity" : similarity
                })
        similar_users = pd.DataFrame(SimilarityArr).sort_values(by="similarity",ascending=False)
        similar_users = similar_users[similar_users.similar_users != item_input]
        return similar_users
    except Exception as e:
        print("Error Occured",e)

# %%
find_similar_users(int(11880),user_weights,user2user_encoded,user2user_decoded)
# Out:
#    similar_users  similarity
# 9          18491    0.351586
# 8          10818    0.334305
# 7          10777    0.312984
# 6          20924    0.308878
# 5          18520    0.293058
# 4          20984    0.287794
# 3          27436    0.278564
# 2          16713    0.277292
# 1           5207    0.276962
# 0          13970    0.263403

# %%
def showWordCloud(all_genres):
    genres_cloud = WordCloud(width=700,height=400,background_color='white',colormap='gnuplot').generate_from_frequencies(all_genres)
    plt.figure(figsize=(10,8))
    plt.imshow(genres_cloud,interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
from collections import defaultdict

# %%
df.head(1)
# Out:
#       anime_id                      eng_version Score  \
# 3971      5114  Fullmetal Alchemist:Brotherhood  9.19
#
#                                                                    Genres  \
# 3971  Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
#
#      Episodes Type    Premiered  Members
# 3971       64   TV  Spring 2009  2248456

# %%
def getFavGenre(frame , plot=False):
    frame.dropna(inplace=False)
    all_genres = defaultdict(int)

    genres_list = []
    for genres in frame["Genres"]:
        if isinstance(genres,str):
            for genre in genres.split(','):
                genres_list.append(genre)
                all_genres[genre.strip()] += 1

    if plot:
        showWordCloud(all_genres)
    
    return genres_list

# %%
rating_df.head(2)
# Out:
#    user_id  anime_id  rating  user  anime
# 0     6624     23321     0.8  1658   1193
# 1     6359     12549     0.0  1603   1302

# %%
def get_user_preferences(user_id , rating_df , df ,plot=False):

    animes_watched_by_user = rating_df[rating_df.user_id == user_id]

    user_rating_percentile = np.percentile(animes_watched_by_user.rating , 75)

    animes_watched_by_user = animes_watched_by_user[animes_watched_by_user.rating >= user_rating_percentile]

    top_animes_user = (
        animes_watched_by_user.sort_values(by="rating" , ascending=False).anime_id.values
    )

    anime_df_rows = df[df["anime_id"].isin(top_animes_user)]
    anime_df_rows = anime_df_rows[["eng_version","Genres"]]

    if plot:
        getFavGenre(anime_df_rows,plot)


    return anime_df_rows

# %%
get_user_preferences(11880 , rating_df, df , plot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 get_user_preferences(11880 , rating_df, df , plot=True)
#
# Cell In[143], line 17, in get_user_preferences(user_id, rating_df, df, plot)
#      14 anime_df_rows = anime_df_rows[["eng_version","Genres"]]
#      16 if plot:
# ---> 17     getFavGenre(anime_df_rows,plot)
#      20 return anime_df_rows
#
# Cell In[141], line 13, in getFavGenre(frame, plot)
#      10             all_genres[genre.strip()] += 1
#      12 if plot:
# ---> 13     showWordCloud(all_genres)
#      15 return genres_list
#
# Cell In[138], line 2, in showWordCloud(all_genres)
#       1 def showWordCloud(all_genres):
# ----> 2     genres_cloud = WordCloud(width=700,height=400,background_color='white',colormap='gnuplot').generate_from_frequencies(all_genres)
#       3     plt.figure(figsize=(10,8))
#       4     plt.imshow(genres_cloud,interpolation="bilinear")
#
# NameError: name 'WordCloud' is not defined

# %%
def get_user_recommendations(similar_users , user_pref ,df , synopsis_df, rating_df, n=10):

    recommended_animes = []
    anime_list = []

    for user_id in similar_users.similar_users.values:
        pref_list = get_user_preferences(int(user_id) , rating_df, df)

        pref_list = pref_list[~pref_list.eng_version.isin(user_pref.eng_version.values)]

        if not pref_list.empty:
            anime_list.append(pref_list.eng_version.values)

    if anime_list:
            anime_list = pd.DataFrame(anime_list)

            sorted_list = pd.DataFrame(pd.Series(anime_list.values.ravel()).value_counts()).head(n)

            for i,anime_name in enumerate(sorted_list.index):
                n_user_pref = sorted_list[sorted_list.index == anime_name].values[0][0]

                if isinstance(anime_name,str):
                    frame = getAnimeFrame(anime_name,df)
                    anime_id = frame.anime_id.values[0]
                    genre = frame.Genres.values[0]
                    synopsis = getSynopsis(int(anime_id),synopsis_df)

                    recommended_animes.append({
                        "n" : n_user_pref,
                        "anime_name" : anime_name,
                        "Genres" : genre,
                        "Synopsis": synopsis
                    })
    return pd.DataFrame(recommended_animes).head(n)

# %%
similar_users =find_similar_users(int(11880),user_weights,user2user_encoded,user2user_decoded)
print(similar_users)
# Out:
#    similar_users  similarity
# 9          18491    0.351586
# 8          10818    0.334305
# 7          10777    0.312984
# 6          20924    0.308878
# 5          18520    0.293058
# 4          20984    0.287794
# 3          27436    0.278564
# 2          16713    0.277292
# 1           5207    0.276962
# 0          13970    0.263403

# %%
user_pref = get_user_preferences(11880 , rating_df, df , plot=False)
print(user_pref)
# Out:
#                           eng_version  \
# 3971  Fullmetal Alchemist:Brotherhood
# 9913                 Gintama Season 4
# 6474                  Hunter x Hunter
# 6006                 Gintama Season 2
# 741     Legend of the Galactic Heroes
# ...                               ...
# 2575              Shootfighter Tekken
# 8064                 Samurai Flamenco
# 510                        Venus Wars
# 6864                Saint Seiya Omega
# 9796                Garo:Crimson Moon
#
#                                                                    Genres
# 3971  Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 9913         Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen
# 6474                     Action, Adventure, Fantasy, Shounen, Super Power
# 6006         Action, Sci-Fi, Comedy, Historical, Parody, Samurai, Shounen
# 741                                        Military, Sci-Fi, Space, Drama
# ...                                                                   ...
# 2575                                        Action, Martial Arts, Shounen
# 8064                                  Action, Comedy, Parody, Super Power
# 510                                      Action, Sci-Fi, Adventure, Space
# 6864                                  Action, Adventure, Fantasy, Shounen
# 9796                         Action, Demons, Fantasy, Magic, Supernatural
#
# [190 rows x 2 columns]

# %%
recommended_animes = []
anime_list = []

for user_id in similar_users.similar_users.values:
    pref_list = get_user_preferences(int(user_id) , rating_df, df)
    print(user_id)
    print(pref_list)

    pref_list = pref_list[~pref_list.eng_version.isin(user_pref.eng_version.values)]
    print(pref_list)
# Out:
# 18491
#                                                              eng_version  \
# 3971                                     Fullmetal Alchemist:Brotherhood
# 5683                                                         Steins;Gate
# 9886                                                      A Silent Voice
# 12898                              March Comes In Like A Lion 2nd Season
# 3537                                               Clannad ~After Story~
# ...                                                                  ...
# 1020                                           Pokemon:Jirachi Wishmaker
# 12453                         Death March to the Parallel World Rhapsody
# 14822                                                 Demon Lord, Retry!
# 15705  That Time I Got Reincarnated as a Slime:Tales - Veldora's Journal
# 11608                                                    Eromanga Sensei
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 5683                                                      Thriller, Sci-Fi
# 9886                                                Drama, School, Shounen
# 12898                                   Drama, Game, Seinen, Slice of Life
# 3537                   Slice of Life, Comedy, Supernatural, Drama, Romance
# ...                                                                    ...
# 1020                               Adventure, Comedy, Kids, Drama, Fantasy
# 12453                                            Adventure, Fantasy, Harem
# 14822                                           Action, Adventure, Fantasy
# 15705                                             Comedy, Fantasy, Shounen
# 11608                                        Comedy, Drama, Romance, Ecchi
#
# [125 rows x 2 columns]
#                                                              eng_version  \
# 5683                                                         Steins;Gate
# 9886                                                      A Silent Voice
# 12898                              March Comes In Like A Lion 2nd Season
# 3537                                               Clannad ~After Story~
# 14306                                                  Mob Psycho 100 II
# ...                                                                  ...
# 1020                                           Pokemon:Jirachi Wishmaker
# 12453                         Death March to the Parallel World Rhapsody
# 14822                                                 Demon Lord, Retry!
# 15705  That Time I Got Reincarnated as a Slime:Tales - Veldora's Journal
# 11608                                                    Eromanga Sensei
#
#                                                     Genres
# 5683                                      Thriller, Sci-Fi
# 9886                                Drama, School, Shounen
# 12898                   Drama, Game, Seinen, Slice of Life
# 3537   Slice of Life, Comedy, Supernatural, Drama, Romance
# 14306          Action, Slice of Life, Comedy, Supernatural
# ...                                                    ...
# 1020               Adventure, Comedy, Kids, Drama, Fantasy
# 12453                            Adventure, Fantasy, Harem
# 14822                           Action, Adventure, Fantasy
# 15705                             Comedy, Fantasy, Shounen
# 11608                        Comedy, Drama, Romance, Ecchi
#
# [115 rows x 2 columns]
# 10818
#                                      eng_version  \
# 3971             Fullmetal Alchemist:Brotherhood
# 5683                                 Steins;Gate
# 741                Legend of the Galactic Heroes
# 9886                              A Silent Voice
# 3537                       Clannad ~After Story~
# ...                                          ...
# 7395                             Flowers of Evil
# 14357  Ms. vampire who lives in my neighborhood.
# 9480                             Yurikuma Arashi
# 727                                 NieA Under 7
# 2831             Toki no Tabibito: Time Stranger
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 5683                                                      Thriller, Sci-Fi
# 741                                         Military, Sci-Fi, Space, Drama
# 9886                                                Drama, School, Shounen
# 3537                   Slice of Life, Comedy, Supernatural, Drama, Romance
# ...                                                                    ...
# 7395                        Psychological, Drama, Romance, School, Shounen
# 14357              Comedy, Shoujo Ai, Slice of Life, Supernatural, Vampire
# 9480              Psychological, Drama, Fantasy, School, Seinen, Shoujo Ai
# 727                                          Comedy, Sci-Fi, Slice of Life
# 2831                                    Action, Adventure, Romance, Sci-Fi
#
# [159 rows x 2 columns]
#                                      eng_version  \
# 5683                                 Steins;Gate
# 9886                              A Silent Voice
# 3537                       Clannad ~After Story~
# 14306                          Mob Psycho 100 II
# 176                                Spirited Away
# ...                                          ...
# 7395                             Flowers of Evil
# 14357  Ms. vampire who lives in my neighborhood.
# 9480                             Yurikuma Arashi
# 727                                 NieA Under 7
# 2831             Toki no Tabibito: Time Stranger
#
#                                                          Genres
# 5683                                           Thriller, Sci-Fi
# 9886                                     Drama, School, Shounen
# 3537        Slice of Life, Comedy, Supernatural, Drama, Romance
# 14306               Action, Slice of Life, Comedy, Supernatural
# 176                              Adventure, Supernatural, Drama
# ...                                                         ...
# 7395             Psychological, Drama, Romance, School, Shounen
# 14357   Comedy, Shoujo Ai, Slice of Life, Supernatural, Vampire
# 9480   Psychological, Drama, Fantasy, School, Seinen, Shoujo Ai
# 727                               Comedy, Sci-Fi, Slice of Life
# 2831                         Action, Adventure, Romance, Sci-Fi
#
# [130 rows x 2 columns]
# 10777
#                                                                              eng_version  \
# 3971                                                     Fullmetal Alchemist:Brotherhood
# 5683                                                                         Steins;Gate
# 14963                                                    Attack on Titan Season 3 Part 2
# 9886                                                                      A Silent Voice
# 12898                                              March Comes In Like A Lion 2nd Season
# ...                                                                                  ...
# 8551                                                                 Sword Art Online II
# 15524  Hensuki:Are you willing to fall in love with a pervert, as long as she's a cutie?
# 10366                                                                          Danchigai
# 12966                                                    Ms. Koizumi Loves Ramen Noodles
# 11608                                                                    Eromanga Sensei
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 5683                                                      Thriller, Sci-Fi
# 14963      Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 9886                                                Drama, School, Shounen
# 12898                                   Drama, Game, Seinen, Slice of Life
# ...                                                                    ...
# 8551                             Action, Game, Adventure, Romance, Fantasy
# 15524                                Comedy, Ecchi, Harem, Romance, School
# 10366                                                Comedy, Slice of Life
# 12966                                                Comedy, Slice of Life
# 11608                                        Comedy, Drama, Romance, Ecchi
#
# [357 rows x 2 columns]
#                                                                              eng_version  \
# 5683                                                                         Steins;Gate
# 14963                                                    Attack on Titan Season 3 Part 2
# 9886                                                                      A Silent Voice
# 12898                                              March Comes In Like A Lion 2nd Season
# 11308                                                                         Your Name.
# ...                                                                                  ...
# 8551                                                                 Sword Art Online II
# 15524  Hensuki:Are you willing to fall in love with a pervert, as long as she's a cutie?
# 10366                                                                          Danchigai
# 12966                                                    Ms. Koizumi Loves Ramen Noodles
# 11608                                                                    Eromanga Sensei
#
#                                                                 Genres
# 5683                                                  Thriller, Sci-Fi
# 14963  Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 9886                                            Drama, School, Shounen
# 12898                               Drama, Game, Seinen, Slice of Life
# 11308                             Romance, Supernatural, School, Drama
# ...                                                                ...
# 8551                         Action, Game, Adventure, Romance, Fantasy
# 15524                            Comedy, Ecchi, Harem, Romance, School
# 10366                                            Comedy, Slice of Life
# 12966                                            Comedy, Slice of Life
# 11608                                    Comedy, Drama, Romance, Ecchi
#
# [309 rows x 2 columns]
# 20924
#                                             eng_version  \
# 3971                    Fullmetal Alchemist:Brotherhood
# 5683                                        Steins;Gate
# 14963                   Attack on Titan Season 3 Part 2
# 6474                                    Hunter x Hunter
# 9886                                     A Silent Voice
# ...                                                 ...
# 11888                     Hitori no Shita - The Outcast
# 14614                               Domestic Girlfriend
# 15297                              Kemono Michi:Rise Up
# 14403  Fate/Extra: Last Encore - Illustrias Tendousetsu
# 11681                            Fate/Extra:Last Encore
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 5683                                                      Thriller, Sci-Fi
# 14963      Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 6474                      Action, Adventure, Fantasy, Shounen, Super Power
# 9886                                                Drama, School, Shounen
# ...                                                                    ...
# 11888                                    Action, Super Power, Supernatural
# 14614                                      Drama, Romance, School, Shounen
# 15297                                             Comedy, Fantasy, Shounen
# 14403                                               Action, Fantasy, Magic
# 11681                                               Action, Fantasy, Magic
#
# [400 rows x 2 columns]
#                                             eng_version  \
# 5683                                        Steins;Gate
# 14963                   Attack on Titan Season 3 Part 2
# 9886                                     A Silent Voice
# 12898             March Comes In Like A Lion 2nd Season
# 11308                                        Your Name.
# ...                                                 ...
# 11888                     Hitori no Shita - The Outcast
# 14614                               Domestic Girlfriend
# 15297                              Kemono Michi:Rise Up
# 14403  Fate/Extra: Last Encore - Illustrias Tendousetsu
# 11681                            Fate/Extra:Last Encore
#
#                                                                 Genres
# 5683                                                  Thriller, Sci-Fi
# 14963  Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 9886                                            Drama, School, Shounen
# 12898                               Drama, Game, Seinen, Slice of Life
# 11308                             Romance, Supernatural, School, Drama
# ...                                                                ...
# 11888                                Action, Super Power, Supernatural
# 14614                                  Drama, Romance, School, Shounen
# 15297                                         Comedy, Fantasy, Shounen
# 14403                                           Action, Fantasy, Magic
# 11681                                           Action, Fantasy, Magic
#
# [356 rows x 2 columns]
# 18520
#                                   eng_version  \
# 3971          Fullmetal Alchemist:Brotherhood
# 5683                              Steins;Gate
# 6474                          Hunter x Hunter
# 12898   March Comes In Like A Lion 2nd Season
# 2656   Code Geass:Lelouch of the Rebellion R2
# ...                                       ...
# 2280                 Mei and the Baby Cat Bus
# 11632                             Scum's Wish
# 2038                     Alps no Shoujo Heidi
# 7240   The "Hentai" Prince and the Stony Cat.
# 12706                           Love and Lies
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 5683                                                      Thriller, Sci-Fi
# 6474                      Action, Adventure, Fantasy, Shounen, Super Power
# 12898                                   Drama, Game, Seinen, Slice of Life
# 2656                   Action, Military, Sci-Fi, Super Power, Drama, Mecha
# ...                                                                    ...
# 2280                                                    Adventure, Fantasy
# 11632                                       Drama, Romance, School, Seinen
# 2038                                      Slice of Life, Historical, Drama
# 7240                          Harem, Comedy, Supernatural, Romance, School
# 12706                                               Drama, Romance, School
#
# [138 rows x 2 columns]
#                                   eng_version  \
# 5683                              Steins;Gate
# 12898   March Comes In Like A Lion 2nd Season
# 2656   Code Geass:Lelouch of the Rebellion R2
# 14306                       Mob Psycho 100 II
# 8883                        Your Lie in April
# ...                                       ...
# 2280                 Mei and the Baby Cat Bus
# 11632                             Scum's Wish
# 2038                     Alps no Shoujo Heidi
# 7240   The "Hentai" Prince and the Stony Cat.
# 12706                           Love and Lies
#
#                                                     Genres
# 5683                                      Thriller, Sci-Fi
# 12898                   Drama, Game, Seinen, Slice of Life
# 2656   Action, Military, Sci-Fi, Super Power, Drama, Mecha
# 14306          Action, Slice of Life, Comedy, Supernatural
# 8883                Drama, Music, Romance, School, Shounen
# ...                                                    ...
# 2280                                    Adventure, Fantasy
# 11632                       Drama, Romance, School, Seinen
# 2038                      Slice of Life, Historical, Drama
# 7240          Harem, Comedy, Supernatural, Romance, School
# 12706                               Drama, Romance, School
#
# [111 rows x 2 columns]
# 20984
#                                   eng_version  \
# 6474                          Hunter x Hunter
# 9886                           A Silent Voice
# 11308                              Your Name.
# 833                                   Gintama
# 11624                     Haikyu!! 3rd Season
# ...                                       ...
# 16788    King's Raid: Ishi wo Tsugumono-tachi
# 16157  Peter Grill and the Philosopher's Time
# 14465                   Isekai Cheat Magician
# 15165        Shironeko Project ZERO CHRONICLE
# 15953                                 Gibiate
#
#                                                              Genres
# 6474               Action, Adventure, Fantasy, Shounen, Super Power
# 9886                                         Drama, School, Shounen
# 11308                          Romance, Supernatural, School, Drama
# 833    Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen
# 11624                        Comedy, Sports, Drama, School, Shounen
# ...                                                             ...
# 16788                             Action, Adventure, Magic, Fantasy
# 16157                                 Harem, Comedy, Ecchi, Fantasy
# 14465                                    Action, Adventure, Fantasy
# 15165                             Action, Adventure, Magic, Fantasy
# 15953                Action, Horror, Martial Arts, Samurai, Fantasy
#
# [348 rows x 2 columns]
#                                   eng_version  \
# 9886                           A Silent Voice
# 11308                              Your Name.
# 11624                     Haikyu!! 3rd Season
# 9895                      Haikyu!! 2nd Season
# 14313                            Vinland Saga
# ...                                       ...
# 16788    King's Raid: Ishi wo Tsugumono-tachi
# 16157  Peter Grill and the Philosopher's Time
# 14465                   Isekai Cheat Magician
# 15165        Shironeko Project ZERO CHRONICLE
# 15953                                 Gibiate
#
#                                                Genres
# 9886                           Drama, School, Shounen
# 11308            Romance, Supernatural, School, Drama
# 11624          Comedy, Sports, Drama, School, Shounen
# 9895           Comedy, Sports, Drama, School, Shounen
# 14313    Action, Adventure, Drama, Historical, Seinen
# ...                                               ...
# 16788               Action, Adventure, Magic, Fantasy
# 16157                   Harem, Comedy, Ecchi, Fantasy
# 14465                      Action, Adventure, Fantasy
# 15165               Action, Adventure, Magic, Fantasy
# 15953  Action, Horror, Martial Arts, Samurai, Fantasy
#
# [309 rows x 2 columns]
# 27436
#                                         eng_version  \
# 3971                Fullmetal Alchemist:Brotherhood
# 5683                                    Steins;Gate
# 14963               Attack on Titan Season 3 Part 2
# 6474                                Hunter x Hunter
# 12898         March Comes In Like A Lion 2nd Season
# ...                                             ...
# 7184                       Maoyu ~ Archenemy & Hero
# 14356                                   Planet With
# 9110   Chaika -The Coffin Princess- Avenging Battle
# 11634   Akashic Records of Bastard Magic Instructor
# 13283           Angolmois:Record of Mongol Invasion
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 5683                                                      Thriller, Sci-Fi
# 14963      Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 6474                      Action, Adventure, Fantasy, Shounen, Super Power
# 12898                                   Drama, Game, Seinen, Slice of Life
# ...                                                                    ...
# 7184                                   Adventure, Demons, Romance, Fantasy
# 14356                                                Action, Mecha, Sci-Fi
# 9110                           Action, Adventure, Comedy, Romance, Fantasy
# 11634                                       Action, Magic, Fantasy, School
# 13283                         Action, Drama, Historical, Military, Samurai
#
# [231 rows x 2 columns]
#                                         eng_version  \
# 5683                                    Steins;Gate
# 14963               Attack on Titan Season 3 Part 2
# 12898         March Comes In Like A Lion 2nd Season
# 2656         Code Geass:Lelouch of the Rebellion R2
# 14306                             Mob Psycho 100 II
# ...                                             ...
# 7184                       Maoyu ~ Archenemy & Hero
# 14356                                   Planet With
# 9110   Chaika -The Coffin Princess- Avenging Battle
# 11634   Akashic Records of Bastard Magic Instructor
# 13283           Angolmois:Record of Mongol Invasion
#
#                                                                 Genres
# 5683                                                  Thriller, Sci-Fi
# 14963  Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 12898                               Drama, Game, Seinen, Slice of Life
# 2656               Action, Military, Sci-Fi, Super Power, Drama, Mecha
# 14306                      Action, Slice of Life, Comedy, Supernatural
# ...                                                                ...
# 7184                               Adventure, Demons, Romance, Fantasy
# 14356                                            Action, Mecha, Sci-Fi
# 9110                       Action, Adventure, Comedy, Romance, Fantasy
# 11634                                   Action, Magic, Fantasy, School
# 13283                     Action, Drama, Historical, Military, Samurai
#
# [170 rows x 2 columns]
# 16713
#                            eng_version  \
# 3971   Fullmetal Alchemist:Brotherhood
# 6006                  Gintama Season 2
# 11308                       Your Name.
# 3537             Clannad ~After Story~
# 833                            Gintama
# ...                                ...
# 2096                Superflat Monogram
# 6247                           Anemone
# 7496                           My Life
# 6924         The Life of Budori Gusuko
# 3494   Chuumon no Ooi Ryouriten (1991)
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 6006          Action, Sci-Fi, Comedy, Historical, Parody, Samurai, Shounen
# 11308                                 Romance, Supernatural, School, Drama
# 3537                   Slice of Life, Comedy, Supernatural, Drama, Romance
# 833           Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen
# ...                                                                    ...
# 2096                                                    Adventure, Fantasy
# 6247                                            Magic, Supernatural, Drama
# 7496                                                  Slice of Life, Drama
# 6924                                   Slice of Life, Kids, Drama, Fantasy
# 3494                                         Horror, Supernatural, Fantasy
#
# [197 rows x 2 columns]
#                                   eng_version  \
# 11308                              Your Name.
# 3537                    Clannad ~After Story~
# 2656   Code Geass:Lelouch of the Rebellion R2
# 176                             Spirited Away
# 25               Samurai X:Trust and Betrayal
# ...                                       ...
# 2096                       Superflat Monogram
# 6247                                  Anemone
# 7496                                  My Life
# 6924                The Life of Budori Gusuko
# 3494          Chuumon no Ooi Ryouriten (1991)
#
#                                                                    Genres
# 11308                                Romance, Supernatural, School, Drama
# 3537                  Slice of Life, Comedy, Supernatural, Drama, Romance
# 2656                  Action, Military, Sci-Fi, Super Power, Drama, Mecha
# 176                                        Adventure, Supernatural, Drama
# 25     Action, Historical, Drama, Romance, Martial Arts, Samurai, Shounen
# ...                                                                   ...
# 2096                                                   Adventure, Fantasy
# 6247                                           Magic, Supernatural, Drama
# 7496                                                 Slice of Life, Drama
# 6924                                  Slice of Life, Kids, Drama, Fantasy
# 3494                                        Horror, Supernatural, Fantasy
#
# [174 rows x 2 columns]
# 5207
#                            eng_version  \
# 3971   Fullmetal Alchemist:Brotherhood
# 14963  Attack on Titan Season 3 Part 2
# 9886                    A Silent Voice
# 11308                       Your Name.
# 3537             Clannad ~After Story~
# ...                                ...
# 2048                    Mizu no Kotoba
# 6674                    Dwaeji-ui Wang
# 2962    Franz Kafka's A Country Doctor
# 949            The Little Norse Prince
# 3991                       Noisy Birth
#
#                                                                     Genres
# 3971   Action, Military, Adventure, Comedy, Drama, Magic, Fantasy, Shounen
# 14963      Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 9886                                                Drama, School, Shounen
# 11308                                 Romance, Supernatural, School, Drama
# 3537                   Slice of Life, Comedy, Supernatural, Drama, Romance
# ...                                                                    ...
# 2048                                          Drama, Psychological, Sci-Fi
# 6674                                Psychological, Drama, Thriller, Seinen
# 2962                            Dementia, Drama, Historical, Psychological
# 949                                                Adventure, Drama, Magic
# 3991                                                       Dementia, Music
#
# [246 rows x 2 columns]
#                                   eng_version  \
# 14963         Attack on Titan Season 3 Part 2
# 9886                           A Silent Voice
# 11308                              Your Name.
# 3537                    Clannad ~After Story~
# 2656   Code Geass:Lelouch of the Rebellion R2
# ...                                       ...
# 2048                           Mizu no Kotoba
# 6674                           Dwaeji-ui Wang
# 2962           Franz Kafka's A Country Doctor
# 949                   The Little Norse Prince
# 3991                              Noisy Birth
#
#                                                                 Genres
# 14963  Action, Drama, Fantasy, Military, Mystery, Shounen, Super Power
# 9886                                            Drama, School, Shounen
# 11308                             Romance, Supernatural, School, Drama
# 3537               Slice of Life, Comedy, Supernatural, Drama, Romance
# 2656               Action, Military, Sci-Fi, Super Power, Drama, Mecha
# ...                                                                ...
# 2048                                      Drama, Psychological, Sci-Fi
# 6674                            Psychological, Drama, Thriller, Seinen
# 2962                        Dementia, Drama, Historical, Psychological
# 949                                            Adventure, Drama, Magic
# 3991                                                   Dementia, Music
#
# [212 rows x 2 columns]
# 13970
#                                eng_version  \
# 5683                           Steins;Gate
# 9886                        A Silent Voice
# 11308                           Your Name.
# 176                          Spirited Away
# 11103     Kizumonogatari III: Reiketsu-hen
# ...                                    ...
# 12200     300 En no Otsukiai Anime Edition
# 12904  In Another World With My Smartphone
# 12471             Anata wa Watashi no Mono
# 6409                              Euphoria
# 11387                     A-Size Classmate
#
#                                                   Genres
# 5683                                    Thriller, Sci-Fi
# 9886                              Drama, School, Shounen
# 11308               Romance, Supernatural, School, Drama
# 176                       Adventure, Supernatural, Drama
# 11103             Action, Mystery, Supernatural, Vampire
# ...                                                  ...
# 12200                                             Hentai
# 12904  Adventure, Harem, Comedy, Magic, Romance, Fantasy
# 12471                                             Hentai
# 6409                                              Hentai
# 11387                                             Hentai
#
# [196 rows x 2 columns]
#                                eng_version  \
# 5683                           Steins;Gate
# 9886                        A Silent Voice
# 11308                           Your Name.
# 176                          Spirited Away
# 11103     Kizumonogatari III: Reiketsu-hen
# ...                                    ...
# 12200     300 En no Otsukiai Anime Edition
# 12904  In Another World With My Smartphone
# 12471             Anata wa Watashi no Mono
# 6409                              Euphoria
# 11387                     A-Size Classmate
#
#                                                   Genres
# 5683                                    Thriller, Sci-Fi
# 9886                              Drama, School, Shounen
# 11308               Romance, Supernatural, School, Drama
# 176                       Adventure, Supernatural, Drama
# 11103             Action, Mystery, Supernatural, Vampire
# ...                                                  ...
# 12200                                             Hentai
# 12904  Adventure, Harem, Comedy, Magic, Romance, Fantasy
# 12471                                             Hentai
# 6409                                              Hentai
# 11387                                             Hentai
#
# [180 rows x 2 columns]

# %%
if not pref_list.empty:
    anime_list.append(pref_list.eng_version.values)
    print(anime_list)
# Out:
# [array(['Steins;Gate', 'A Silent Voice', 'Your Name.', 'Spirited Away',
#        'Kizumonogatari III: Reiketsu-hen', 'Your Lie in April',
#        'Kaguya-sama:Love is War Season 2', 'Princess Mononoke',
#        'Rascal Does Not Dream of a Dreaming Girl', "Howl's Moving Castle",
#        'The Promised Neverland', 'Death Note',
#        'Kizumonogatari Part 2:Nekketsu', 'Steins;Gate 0',
#        'Saenai Heroine no Sodatekata Fine', 'Attack on Titan',
#        'Owarimonogatari', 'Kaguya-sama:Love is War',
#        'Weathering With You', 'Kizumonogatari Part 1:Tekketsu',
#        'Rascal Does Not Dream of Bunny Girl Senpai', 'Shirobako',
#        'Shelter', 'My Neighbor Totoro',
#        "KonoSuba:God's Blessing on This Wonderful World! 2",
#        'Re:ZERO -Starting Life in Another World-',
#        'Steins;Gate: Kyoukaimenjou no Missing Link - Divide By Zero',
#        'Hinamatsuri', 'No Game, No Life', 'Asobi Asobase:Workshop of Fun',
#        "Girls' Last Tour", 'Nisemonogatari',
#        "KonoSuba:God's Blessing on This Wonderful World!", 'Angel Beats!',
#        'Food Wars! The Third Plate', 'Tsukimonogatari',
#        'Food Wars! The Third Plate:Totsuki Train Arc',
#        "KonoSuba:God's Blessing on This Wonderful World! 2:God's blessing on this wonderful Art!",
#        'That Time I Got Reincarnated as a Slime',
#        "Miss Kobayashi's Dragon Maid", 'The Rising of the Shield Hero',
#        'The Saga of Tanya the Evil', 'Hanamonogatari',
#        'Is the Order a Rabbit? Bloom', "Monthly Girls' Nozaki-kun",
#        'Wotakoi:Love is Hard for Otaku', 'Overlord', 'Overlord III',
#        'Plastic Memories', 'Date A Live II: Kurumi Star Festival',
#        'Kono Subarashii Sekai ni Shukufuku wo!: Kono Subarashii Choker ni Shukufuku wo!',
#        'Classroom of the Elite', 'Little Witch Academia',
#        'Is the Order a Rabbit??', 'Ghost Hunt', 'The Cat Returns',
#        'Saekano:How to Raise a Boring Girlfriend .flat', 'Overlord II',
#        'BanG Dream! Garupa☆Pico',
#        'Little Witch Academia:The Enchanted Parade', 'Charlotte',
#        'New Game!!', 'Hayate the Combat Butler!!',
#        'The World God Only Knows', 'Prison School', 'Tsuredure Children',
#        'Cells at Work!',
#        'Is It Wrong to Try to Pick Up Girls in a Dungeon?',
#        'School-Live!', 'Recovery of an MMO Junkie', 'New Game!',
#        'Angel Beats! Specials', 'Interviews With Monster Girls',
#        'YuruYuri:Happy Go Lily', 'Is this A Zombie? of the Dead',
#        'Tada Never Falls in Love', "Heaven's Lost Property:Forte",
#        'Another', 'Saekano:How to Raise a Boring Girlfriend',
#        "Heaven's Memo Pad", 'The Future Diary', 'High School DxD New',
#        'Shokugeki no Souma: Ni no Sara OVA', 'Sweetness & Lightning',
#        "Interviews With Monster Girls:The Demi-chans' Summer Break",
#        'Is the Order a Rabbit?', 'O Maidens in Your Savage Season',
#        'Haiyore! Nyaruko-san F', 'Gabriel DropOut',
#        'Angel Beats!: Another Epilogue', 'Charlotte: Tsuyoimono-tachi',
#        'High School DxD BorN',
#        'High School DxD BorN: Yomigaeranai Fushichou',
#        'Is This a Zombie?', 'Kakegurui:Compulsive Gambler',
#        'OreImo Specials', 'Comic Girls', 'Is This a Zombie? OVA',
#        'Recovery of an MMO Junkie Special', 'My Ordinary Life Episode 0',
#        "Haganai:I don't have many friends NEXT", 'High School DxD',
#        "A Sister's All You Need", 'Diary of Our Days at the Breakwater',
#        'Dragon Pilot:Hisone and Masotan', 'Date A Live: Date to Date',
#        'Sankarea:Undying Love', 'Wataten! An Angel Flew Down to Me',
#        'Shokugeki no Souma OVA', "Heaven's Lost Property",
#        'Restaurant to Another World',
#        'Saekano:How to Raise a Boring Girlfriend .flat - Fan Service of Love and Pure heart',
#        'Kakegurui××', 'DARLING in the FRANXX', 'We Never Learn:BOKUBEN',
#        'Another:The Other', 'High School DxD OVA',
#        'High School DxD New: Oppai, Tsutsumimasu!',
#        'High School DxD Hero', 'Umamusume:Pretty Derby',
#        'Sankarea:I, Too, Am... A Zombie...',
#        "Haganai:I don't have many friends",
#        'This Art Club Has a Problem!',
#        'My Mental Choices Are Completely Interfering With My School Romantic Comedy',
#        'Sword Art Online', 'Sankarea OVA', 'Date A Live II',
#        'The "Hentai" Prince and the Stony Cat.',
#        'Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA',
#        'Date A Live', 'Akashic Records of Bastard Magic Instructor',
#        'The Comic Artist and His Assistants',
#        'Haiyore! Nyaruko-san: Yasashii Teki no Shitome-kata',
#        'Tentacle and Witches', 'OreImo',
#        'Is It Wrong to Try to Pick Up Girls in a Dungeon?:Is It Wrong to Expect a Hot Spring in a Dungeon?',
#        'Sword Art Online Alternative: Gun Gale Online', 'To LOVE Ru',
#        'Saenai Heroine no Sodatekata: Ai to Seishun no Service-kai',
#        'Yuragi-sou no Yuuna-san', 'Oreshura',
#        'Attack on Titan:Junior High', 'Oreimo 2', 'Nekopara OVA',
#        'How Not to Summon a Demon Lord', "Armed Girl's Machiavellism",
#        'Hanebado!', "The Ryuo's Work is Never Done!", 'Gamers!',
#        'Girlish Number', 'High School DxD Hero: Taiikukan-ura no Holy',
#        'Asteroid in Love', 'Rosario + Vampire', "Masamune-kun's Revenge",
#        'And you thought there is never a girl online?',
#        'No Game No Life Specials', 'Futa-bu! Mix: Futanari World',
#        'Kanojo wa Dare to demo Sex Suru.', 'Lapis Re:LiGHTs',
#        "Hensuki:Are you willing to fall in love with a pervert, as long as she's a cutie?",
#        'Tawawa on Monday Specials', 'Imouto sae Ireba Ii. (ONA)',
#        'Love and Lies', 'Miru Tights',
#        "Arifureta:From Commonplace to World's Strongest",
#        'Miyakawa-ke no Kuufuku', 'Absolute Duo', 'Mahou Shoujo Elena',
#        'Citrus', 'Eromanga Sensei', 'Getsuyoubi no Tawawa',
#        'Saikin, Imouto no Yousu ga Chotto Okashiinda ga. OVA',
#        'Mirai no Watashi', 'My Girlfriend is Shobitch',
#        'Recently, my sister is unusual.',
#        '300 En no Otsukiai Anime Edition',
#        'In Another World With My Smartphone', 'Anata wa Watashi no Mono',
#        'Euphoria', 'A-Size Classmate'], dtype=object)]

# %%
anime_list = pd.DataFrame(anime_list)
sorted_list = pd.DataFrame(pd.Series(anime_list.values.ravel()).value_counts()).head(2)
print(sorted_list)
for i,anime_name in enumerate(sorted_list.index):
    print(anime_name)
    n_user_pref = sorted_list[sorted_list.index == anime_name].values[0][0]
    print(n_user_pref)
    if isinstance(anime_name,str):
        frame = getAnimeFrame(anime_name,df)
        anime_id = frame.anime_id.values[0]
        genre = frame.Genres.values[0]
        synopsis = getSynopsis(int(anime_id),synopsis_df)
        recommended_animes.append({
                        "n" : n_user_pref,
                        "anime_name" : anime_name,
                        "Genres" : genre,
                        "Synopsis": synopsis
            })
recommended_animes=pd.DataFrame(recommended_animes).head()
# Out:
#                 count
# Steins;Gate         1
# A Silent Voice      1
# Steins;Gate
# 1
# A Silent Voice
# 1

# %%
recommended_animes
# Out:
#    n      anime_name                  Genres  \
# 0  1     Steins;Gate        Thriller, Sci-Fi
# 1  1  A Silent Voice  Drama, School, Shounen
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Synopsis
# 0  The self-proclaimed mad scientist Rintarou Okabe rents out a room in a rickety old building in Akihabara, where he indulges himself in his hobby of inventing prospective "future gadgets" with fellow lab members: Mayuri Shiina, his air-headed childhood friend, and Hashida Itaru, a perverted hacker nicknamed "Daru." The three pass the time by tinkering with their most promising contraption yet, a machine dubbed the "Phone Microwave," which performs the strange function of morphing bananas into piles of green gel. Though miraculous in itself, the phenomenon doesn't provide anything concrete in Okabe's search for a scientific breakthrough; that is, until the lab members are spurred into action by a string of mysterious happenings before stumbling upon an unexpected success—the Phone Microwave can send emails to the past, altering the flow of history. Adapted from the critically acclaimed visual novel by 5pb. and Nitroplus, Steins;Gate takes Okabe through the depths of scientific theory and practicality. Forced across the diverging threads of past and present, Okabe must shoulder the burdens that come with holding the key to the realm of time.
# 1                                                                                                                                                                                                                                          s a wild youth, elementary school student Shouya Ishida sought to beat boredom in the cruelest ways. When the deaf Shouko Nishimiya transfers into his class, Shouya and the rest of his class thoughtlessly bully her for fun. However, when her mother notifies the school, he is singled out and blamed for everything done to her. With Shouko transferring out of the school, Shouya is left at the mercy of his classmates. He is heartlessly ostracized all throughout elementary and middle school, while teachers turn a blind eye. Now in his third year of high school, Shouya is still plagued by his wrongdoings as a young boy. Sincerely regretting his past actions, he sets out on a journey of redemption: to meet Shouko once more and make amends. Koe no Katachi tells the heartwarming tale of Shouya's reunion with Shouko and his honest attempts to redeem himself, all while being continually haunted by the shadows of his past.

# %%
similar_users =find_similar_users(int(11880),user_weights,user2user_encoded,user2user_decoded)

# %%
user_pref = get_user_preferences(11880 , rating_df, df , plot=False)

# %%
get_user_recommendations(similar_users,user_pref,df, synopsis_df,rating_df,n=2)
# Out:
#    n       anime_name  \
# 0  8       Death Note
# 1  7  Attack on Titan
#
#                                                             Genres  \
# 0  Mystery, Police, Psychological, Supernatural, Thriller, Shounen
# 1  Action, Military, Mystery, Super Power, Drama, Fantasy, Shounen
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Synopsis
# 0                                                                                                               shinigami, as a god of death, can kill any person—provided they see their victim's face and write their victim's name in a notebook called a Death Note. One day, Ryuk, bored by the shinigami lifestyle and interested in seeing how a human would use a Death Note, drops one into the human realm. High school student and prodigy Light Yagami stumbles upon the Death Note and—since he deplores the state of the world—tests the deadly notebook by writing a criminal's name in it. When the criminal dies immediately following his experiment with the Death Note, Light is greatly surprised and quickly recognizes how devastating the power that has fallen into his hands could be. With this divine capability, Light decides to extinguish all criminals in order to build a new world where crime does not exist and people worship him as a god. Police, however, quickly discover that a serial killer is targeting criminals and, consequently, try to apprehend the culprit. To do this, the Japanese investigators count on the assistance of the best detective in the world: a young and eccentric man known only by the name of L.
# 1  Centuries ago, mankind was slaughtered to near extinction by monstrous humanoid creatures called titans, forcing humans to hide in fear behind enormous concentric walls. What makes these giants truly terrifying is that their taste for human flesh is not born out of hunger but what appears to be out of pleasure. To ensure their survival, the remnants of humanity began living within defensive barriers, resulting in one hundred years without a single titan encounter. However, that fragile calm is soon shattered when a colossal titan manages to breach the supposedly impregnable outer wall, reigniting the fight for survival against the man-eating abominations. After witnessing a horrific personal loss at the hands of the invading creatures, Eren Yeager dedicates his life to their eradication by enlisting into the Survey Corps, an elite military unit that combats the merciless humanoids outside the protection of the walls. Based on Hajime Isayama's award-winning manga, Shingeki no Kyojin follows Eren, along with his adopted sister Mikasa Ackerman and his childhood friend Armin Arlert, as they join the brutal war against the titans and race to discover a way of defeating them before the last walls are breached.

# %% [markdown]
# ### HYBRID RECOMMENDER SYSTEM

# %%
def hybrid_recommendation(user_id , user_weight=0.5, content_weight =0.5):

    ## User Recommndation

    similar_users =find_similar_users(user_id,user_weights,user2user_encoded,user2user_decoded)
    user_pref = get_user_preferences(user_id , rating_df, df)
    user_recommended_animes =get_user_recommendations(similar_users,user_pref,df, synopsis_df,rating_df)
    

    user_recommended_anime_list = user_recommended_animes["anime_name"].tolist()
    print(user_recommended_anime_list)

    #### Content recommendation
    content_recommended_animes = []

    for anime in user_recommended_anime_list:
        similar_animes = find_similar_animes(anime, anime_weights, anime2anime_encoded, anime2anime_decoded, df, synopsis_df)

        if similar_animes is not None and not similar_animes.empty:
            content_recommended_animes.extend(similar_animes["name"].tolist())
        else:
            print(f"No similar anime found {anime}")
    
    combined_scores = {}

    for anime in user_recommended_anime_list:
        combined_scores[anime] = combined_scores.get(anime,0) + user_weight

    for anime in content_recommended_animes:
        combined_scores[anime] = combined_scores.get(anime,0) + content_weight  

    sorted_animes = sorted(combined_scores.items() , key=lambda x:x[1] , reverse=True)

    return [anime for anime , score in sorted_animes[:10]]

# %%
hybrid_recommendation(11880)
# Out:
# ['Death Note', 'Angel Beats!', 'Clannad', 'The Girl Who Leapt Through Time', 'Code Geass:Lelouch of the Rebellion R2', 'Clannad ~After Story~', 'Hotarubi no Mori e', 'Nisemonogatari', 'No Game No Life: Zero', 'A Silent Voice']
# ['Death Note',
#  'Angel Beats!',
#  'Clannad',
#  'The Girl Who Leapt Through Time',
#  'Code Geass:Lelouch of the Rebellion R2',
#  'Clannad ~After Story~',
#  'Hotarubi no Mori e',
#  'Nisemonogatari',
#  'No Game No Life: Zero',
#  'A Silent Voice']
